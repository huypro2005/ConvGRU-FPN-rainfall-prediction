# %%
# !unzip /content/dataset_ts.zip -d /content/data
# Out:
# Archive:  /content/dataset_ts.zip
#    creating: /content/data/test/
#    creating: /content/data/test/features/
#   inflating: /content/data/test/features/0000.npy
#   inflating: /content/data/test/features/0001.npy
#   inflating: /content/data/test/features/0002.npy
#   inflating: /content/data/test/features/0003.npy
#   inflating: /content/data/test/features/0004.npy
#   inflating: /content/data/test/features/0005.npy
#   inflating: /content/data/test/features/0006.npy
#   inflating: /content/data/test/features/0007.npy
#   inflating: /content/data/test/features/0008.npy
#   inflating: /content/data/test/features/0009.npy
#   inflating: /content/data/test/features/0010.npy
#   inflating: /content/data/test/features/0011.npy
#   inflating: /content/data/test/features/0012.npy
#   inflating: /content/data/test/features/0013.npy
#   inflating: /content/data/test/features/0014.npy
#   inflating: /content/data/test/features/0015.npy
#   inflating: /content/data/test/features/0016.npy
#   inflating: /content/data/test/features/0017.npy
#   inflating: /content/data/test/features/0018.npy
#   inflating: /content/data/test/features/0019.npy
#   inflating: /content/data/test/features/0020.npy
#   inflating: /content/data/test/features/0021.npy
#   inflating: /content/data/test/features/0022.npy
#   inflating: /content/data/test/features/0023.npy
#   inflating: /content/data/test/features/0024.npy
#   inflating: /content/data/test/features/0025.npy
#   inflating: /content/data/test/features/0026.npy
#   inflating: /content/data/test/features/0027.npy
#   inflating: /content/data/test/features/0028.npy
#   inflating: /content/data/test/features/0029.npy
#   inflating: /content/data/test/features/0030.npy
#   inflating: /content/data/test/features/0031.npy
#   inflating: /content/data/test/features/0032.npy
#   inflating: /content/data/test/features/0033.npy
#   inflating: /content/data/test/features/0034.npy
#   inflating: /content/data/test/features/0035.npy
#   inflating: /content/data/test/features/0036.npy
#   inflating: /content/data/test/features/0037.npy
#   inflating: /content/data/test/features/0038.npy
#   inflating: /content/data/test/features/0039.npy
#   inflating: /content/data/test/features/0040.npy
#   inflating: /content/data/test/features/0041.npy
#   inflating: /content/data/test/features/0042.npy
#   inflating: /content/data/test/features/0043.npy
#   inflating: /content/data/test/features/0044.npy
#   inflating: /content/data/test/features/0045.npy
#   inflating: /content/data/test/features/0046.npy
#   inflating: /content/data/test/features/0047.npy
#   inflating: /content/data/test/features/0048.npy
#   inflating: /content/data/test/features/0049.npy
#   inflating: /content/data/test/features/0050.npy
#   inflating: /content/data/test/features/0051.npy
#   inflating: /content/data/test/features/0052.npy
#   inflating: /content/data/test/features/0053.npy
#   inflating: /content/data/test/features/0054.npy
#   inflating: /content/data/test/features/0055.npy
#   inflating: /content/data/test/features/0056.npy
#   inflating: /content/data/test/features/0057.npy
#   inflating: /content/data/test/features/0058.npy
#   inflating: /content/data/test/features/0059.npy
#   inflating: /content/data/test/features/0060.npy
#   inflating: /content/data/test/features/0061.npy
#   inflating: /content/data/test/features/0062.npy
#   inflating: /content/data/test/features/0063.npy
#   inflating: /content/data/test/features/0064.npy
#   inflating: /content/data/test/features/0065.npy
#   inflating: /content/data/test/features/0066.npy
#   inflating: /content/data/test/features/0067.npy
#   inflating: /content/data/test/features/0068.npy
#   inflating: /content/data/test/features/0069.npy
#   inflating: /content/data/test/features/0070.npy
#   inflating: /content/data/test/features/0071.npy
#   inflating: /content/data/test/features/0072.npy
#   inflating: /content/data/test/features/0073.npy
#   inflating: /content/data/test/features/0074.npy
#   inflating: /content/data/test/features/0075.npy
#   inflating: /content/data/test/features/0076.npy
#   inflating: /content/data/test/features/0077.npy
#   inflating: /content/data/test/features/0078.npy
#   inflating: /content/data/test/features/0079.npy
#   inflating: /content/data/test/features/0080.npy
#   inflating: /content/data/test/features/0081.npy
#   inflating: /content/data/test/features/0082.npy
#   inflating: /content/data/test/features/0083.npy
#   inflating: /content/data/test/features/0084.npy
#   inflating: /content/data/test/features/0085.npy
#   inflating: /content/data/test/features/0086.npy
#   inflating: /content/data/test/features/0087.npy
#   inflating: /content/data/test/features/0088.npy
#   inflating: /content/data/test/features/0089.npy
#   inflating: /content/data/test/features/0090.npy
#   inflating: /content/data/test/features/0091.npy
#   inflating: /content/data/test/features/0092.npy
#   inflating: /content/data/test/features/0093.npy
#   inflating: /content/data/test/features/0094.npy
#   inflating: /content/data/test/features/0095.npy
#   inflating: /content/data/test/features/0096.npy
#   inflating: /content/data/test/features/0097.npy
#   inflating: /content/data/test/features/0098.npy
#   inflating: /content/data/test/features/0099.npy
#   inflating: /content/data/test/features/0100.npy
#   inflating: /content/data/test/features/0101.npy
#   inflating: /content/data/test/features/0102.npy
#   inflating: /content/data/test/features/0103.npy
#   inflating: /content/data/test/features/0104.npy
#   inflating: /content/data/test/features/0105.npy
#   inflating: /content/data/test/features/0106.npy
#   inflating: /content/data/test/features/0107.npy
#   inflating: /content/data/test/features/0108.npy
#   inflating: /content/data/test/features/0109.npy
#   inflating: /content/data/test/features/0110.npy
#   inflating: /content/data/test/features/0111.npy
#   inflating: /content/data/test/features/0112.npy
#   inflating: /content/data/test/features/0113.npy
#   inflating: /content/data/test/features/0114.npy
#   inflating: /content/data/test/features/0115.npy
#   inflating: /content/data/test/features/0116.npy
#   inflating: /content/data/test/features/0117.npy
#   inflating: /content/data/test/features/0118.npy
#   inflating: /content/data/test/features/0119.npy
#   inflating: /content/data/test/features/0120.npy
#   inflating: /content/data/test/features/0121.npy
#   inflating: /content/data/test/features/0122.npy
#   inflating: /content/data/test/features/0123.npy
#   inflating: /content/data/test/features/0124.npy
#   inflating: /content/data/test/features/0125.npy
#   inflating: /content/data/test/features/0126.npy
#   inflating: /content/data/test/features/0127.npy
#   inflating: /content/data/test/features/0128.npy
#   inflating: /content/data/test/features/0129.npy
#   inflating: /content/data/test/features/0130.npy
#   inflating: /content/data/test/features/0131.npy
#   inflating: /content/data/test/features/0132.npy
#   inflating: /content/data/test/features/0133.npy
#   inflating: /content/data/test/features/0134.npy
#   inflating: /content/data/test/features/0135.npy
#   inflating: /content/data/test/features/0136.npy
#   inflating: /content/data/test/features/0137.npy
#   inflating: /content/data/test/features/0138.npy
#   inflating: /content/data/test/features/0139.npy
#   inflating: /content/data/test/features/0140.npy
#   inflating: /content/data/test/features/0141.npy
#   inflating: /content/data/test/features/0142.npy
#   inflating: /content/data/test/features/0143.npy
#   inflating: /content/data/test/features/0144.npy
#   inflating: /content/data/test/features/0145.npy
#   inflating: /content/data/test/features/0146.npy
#   inflating: /content/data/test/features/0147.npy
#   inflating: /content/data/test/features/0148.npy
#   inflating: /content/data/test/features/0149.npy
#   inflating: /content/data/test/features/0150.npy
#   inflating: /content/data/test/features/0151.npy
#   inflating: /content/data/test/features/0152.npy
#   inflating: /content/data/test/features/0153.npy
#   inflating: /content/data/test/features/0154.npy
#   inflating: /content/data/test/features/0155.npy
#   inflating: /content/data/test/features/0156.npy
#   inflating: /content/data/test/features/0157.npy
#   inflating: /content/data/test/features/0158.npy
#   inflating: /content/data/test/features/0159.npy
#   inflating: /content/data/test/features/0160.npy
#   inflating: /content/data/test/features/0161.npy
#   inflating: /content/data/test/features/0162.npy
#   inflating: /content/data/test/features/0163.npy
#   inflating: /content/data/test/features/0164.npy
#   inflating: /content/data/test/features/0165.npy
#   inflating: /content/data/test/features/0166.npy
#   inflating: /content/data/test/features/0167.npy
#   inflating: /content/data/test/features/0168.npy
#   inflating: /content/data/test/features/0169.npy
#   inflating: /content/data/test/features/0170.npy
#   inflating: /content/data/test/features/0171.npy
#   inflating: /content/data/test/features/0172.npy
#   inflating: /content/data/test/features/0173.npy
#   inflating: /content/data/test/features/0174.npy
#   inflating: /content/data/test/features/0175.npy
#   inflating: /content/data/test/features/0176.npy
#   inflating: /content/data/test/features/0177.npy
#   inflating: /content/data/test/features/0178.npy
#   inflating: /content/data/test/features/0179.npy
#   inflating: /content/data/test/features/0180.npy
#   inflating: /content/data/test/features/0181.npy
#   inflating: /content/data/test/features/0182.npy
#   inflating: /content/data/test/features/0183.npy
#    creating: /content/data/test/target/
#   inflating: /content/data/test/target/0000.npy
#   inflating: /content/data/test/target/0001.npy
#   inflating: /content/data/test/target/0002.npy
#   inflating: /content/data/test/target/0003.npy
#   inflating: /content/data/test/target/0004.npy
#   inflating: /content/data/test/target/0005.npy
#   inflating: /content/data/test/target/0006.npy
#   inflating: /content/data/test/target/0007.npy
#   inflating: /content/data/test/target/0008.npy
#   inflating: /content/data/test/target/0009.npy
#   inflating: /content/data/test/target/0010.npy
#   inflating: /content/data/test/target/0011.npy
#   inflating: /content/data/test/target/0012.npy
#   inflating: /content/data/test/target/0013.npy
#   inflating: /content/data/test/target/0014.npy
#   inflating: /content/data/test/target/0015.npy
#   inflating: /content/data/test/target/0016.npy
#   inflating: /content/data/test/target/0017.npy
#   inflating: /content/data/test/target/0018.npy
#   inflating: /content/data/test/target/0019.npy
#   inflating: /content/data/test/target/0020.npy
#   inflating: /content/data/test/target/0021.npy
#   inflating: /content/data/test/target/0022.npy
#   inflating: /content/data/test/target/0023.npy
#   inflating: /content/data/test/target/0024.npy
#   inflating: /content/data/test/target/0025.npy
#   inflating: /content/data/test/target/0026.npy
#   inflating: /content/data/test/target/0027.npy
#   inflating: /content/data/test/target/0028.npy
#   inflating: /content/data/test/target/0029.npy
#   inflating: /content/data/test/target/0030.npy
#   inflating: /content/data/test/target/0031.npy
#   inflating: /content/data/test/target/0032.npy
#   inflating: /content/data/test/target/0033.npy
#   inflating: /content/data/test/target/0034.npy
#   inflating: /content/data/test/target/0035.npy
#   inflating: /content/data/test/target/0036.npy
#   inflating: /content/data/test/target/0037.npy
#   inflating: /content/data/test/target/0038.npy
#   inflating: /content/data/test/target/0039.npy
#   inflating: /content/data/test/target/0040.npy
#   inflating: /content/data/test/target/0041.npy
#   inflating: /content/data/test/target/0042.npy
#   inflating: /content/data/test/target/0043.npy
#   inflating: /content/data/test/target/0044.npy
#   inflating: /content/data/test/target/0045.npy
#   inflating: /content/data/test/target/0046.npy
#   inflating: /content/data/test/target/0047.npy
#   inflating: /content/data/test/target/0048.npy
#   inflating: /content/data/test/target/0049.npy
#   inflating: /content/data/test/target/0050.npy
#   inflating: /content/data/test/target/0051.npy
#   inflating: /content/data/test/target/0052.npy
#   inflating: /content/data/test/target/0053.npy
#   inflating: /content/data/test/target/0054.npy
#   inflating: /content/data/test/target/0055.npy
#   inflating: /content/data/test/target/0056.npy
#   inflating: /content/data/test/target/0057.npy
#   inflating: /content/data/test/target/0058.npy
#   inflating: /content/data/test/target/0059.npy
#   inflating: /content/data/test/target/0060.npy
#   inflating: /content/data/test/target/0061.npy
#   inflating: /content/data/test/target/0062.npy
#   inflating: /content/data/test/target/0063.npy
#   inflating: /content/data/test/target/0064.npy
#   inflating: /content/data/test/target/0065.npy
#   inflating: /content/data/test/target/0066.npy
#   inflating: /content/data/test/target/0067.npy
#   inflating: /content/data/test/target/0068.npy
#   inflating: /content/data/test/target/0069.npy
#   inflating: /content/data/test/target/0070.npy
#   inflating: /content/data/test/target/0071.npy
#   inflating: /content/data/test/target/0072.npy
#   inflating: /content/data/test/target/0073.npy
#   inflating: /content/data/test/target/0074.npy
#   inflating: /content/data/test/target/0075.npy
#   inflating: /content/data/test/target/0076.npy
#   inflating: /content/data/test/target/0077.npy
#   inflating: /content/data/test/target/0078.npy
#   inflating: /content/data/test/target/0079.npy
#   inflating: /content/data/test/target/0080.npy
#   inflating: /content/data/test/target/0081.npy
#   inflating: /content/data/test/target/0082.npy
#   inflating: /content/data/test/target/0083.npy
#   inflating: /content/data/test/target/0084.npy
#   inflating: /content/data/test/target/0085.npy
#   inflating: /content/data/test/target/0086.npy
#   inflating: /content/data/test/target/0087.npy
#   inflating: /content/data/test/target/0088.npy
#   inflating: /content/data/test/target/0089.npy
#   inflating: /content/data/test/target/0090.npy
#   inflating: /content/data/test/target/0091.npy
#   inflating: /content/data/test/target/0092.npy
#   inflating: /content/data/test/target/0093.npy
#   inflating: /content/data/test/target/0094.npy
#   inflating: /content/data/test/target/0095.npy
#   inflating: /content/data/test/target/0096.npy
#   inflating: /content/data/test/target/0097.npy
#   inflating: /content/data/test/target/0098.npy
#   inflating: /content/data/test/target/0099.npy
#   inflating: /content/data/test/target/0100.npy
#   inflating: /content/data/test/target/0101.npy
#   inflating: /content/data/test/target/0102.npy
#   inflating: /content/data/test/target/0103.npy
#   inflating: /content/data/test/target/0104.npy
#   inflating: /content/data/test/target/0105.npy
#   inflating: /content/data/test/target/0106.npy
#   inflating: /content/data/test/target/0107.npy
#   inflating: /content/data/test/target/0108.npy
#   inflating: /content/data/test/target/0109.npy
#   inflating: /content/data/test/target/0110.npy
#   inflating: /content/data/test/target/0111.npy
#   inflating: /content/data/test/target/0112.npy
#   inflating: /content/data/test/target/0113.npy
#   inflating: /content/data/test/target/0114.npy
#   inflating: /content/data/test/target/0115.npy
#   inflating: /content/data/test/target/0116.npy
#   inflating: /content/data/test/target/0117.npy
#   inflating: /content/data/test/target/0118.npy
#   inflating: /content/data/test/target/0119.npy
#   inflating: /content/data/test/target/0120.npy
#   inflating: /content/data/test/target/0121.npy
#   inflating: /content/data/test/target/0122.npy
#   inflating: /content/data/test/target/0123.npy
#   inflating: /content/data/test/target/0124.npy
#   inflating: /content/data/test/target/0125.npy
#   inflating: /content/data/test/target/0126.npy
#   inflating: /content/data/test/target/0127.npy
#   inflating: /content/data/test/target/0128.npy
#   inflating: /content/data/test/target/0129.npy
#   inflating: /content/data/test/target/0130.npy
#   inflating: /content/data/test/target/0131.npy
#   inflating: /content/data/test/target/0132.npy
#   inflating: /content/data/test/target/0133.npy
#   inflating: /content/data/test/target/0134.npy
#   inflating: /content/data/test/target/0135.npy
#   inflating: /content/data/test/target/0136.npy
#   inflating: /content/data/test/target/0137.npy
#   inflating: /content/data/test/target/0138.npy
#   inflating: /content/data/test/target/0139.npy
#   inflating: /content/data/test/target/0140.npy
#   inflating: /content/data/test/target/0141.npy
#   inflating: /content/data/test/target/0142.npy
#   inflating: /content/data/test/target/0143.npy
#   inflating: /content/data/test/target/0144.npy
#   inflating: /content/data/test/target/0145.npy
#   inflating: /content/data/test/target/0146.npy
#   inflating: /content/data/test/target/0147.npy
#   inflating: /content/data/test/target/0148.npy
#   inflating: /content/data/test/target/0149.npy
#   inflating: /content/data/test/target/0150.npy
#   inflating: /content/data/test/target/0151.npy
#   inflating: /content/data/test/target/0152.npy
#   inflating: /content/data/test/target/0153.npy
#   inflating: /content/data/test/target/0154.npy
#   inflating: /content/data/test/target/0155.npy
#   inflating: /content/data/test/target/0156.npy
#   inflating: /content/data/test/target/0157.npy
#   inflating: /content/data/test/target/0158.npy
#   inflating: /content/data/test/target/0159.npy
#   inflating: /content/data/test/target/0160.npy
#   inflating: /content/data/test/target/0161.npy
#   inflating: /content/data/test/target/0162.npy
#   inflating: /content/data/test/target/0163.npy
#   inflating: /content/data/test/target/0164.npy
#   inflating: /content/data/test/target/0165.npy
#   inflating: /content/data/test/target/0166.npy
#   inflating: /content/data/test/target/0167.npy
#   inflating: /content/data/test/target/0168.npy
#   inflating: /content/data/test/target/0169.npy
#   inflating: /content/data/test/target/0170.npy
#   inflating: /content/data/test/target/0171.npy
#   inflating: /content/data/test/target/0172.npy
#   inflating: /content/data/test/target/0173.npy
#   inflating: /content/data/test/target/0174.npy
#   inflating: /content/data/test/target/0175.npy
#   inflating: /content/data/test/target/0176.npy
#   inflating: /content/data/test/target/0177.npy
#   inflating: /content/data/test/target/0178.npy
#   inflating: /content/data/test/target/0179.npy
#   inflating: /content/data/test/target/0180.npy
#   inflating: /content/data/test/target/0181.npy
#   inflating: /content/data/test/target/0182.npy
#   inflating: /content/data/test/target/0183.npy
#    creating: /content/data/train/
#    creating: /content/data/train/features/
#   inflating: /content/data/train/features/0000.npy
#   inflating: /content/data/train/features/0001.npy
#   inflating: /content/data/train/features/0002.npy
#   inflating: /content/data/train/features/0003.npy
#   inflating: /content/data/train/features/0004.npy
#   inflating: /content/data/train/features/0005.npy
#   inflating: /content/data/train/features/0006.npy
#   inflating: /content/data/train/features/0007.npy
#   inflating: /content/data/train/features/0008.npy
#   inflating: /content/data/train/features/0009.npy
#   inflating: /content/data/train/features/0010.npy
#   inflating: /content/data/train/features/0011.npy
#   inflating: /content/data/train/features/0012.npy
#   inflating: /content/data/train/features/0013.npy
#   inflating: /content/data/train/features/0014.npy
#   inflating: /content/data/train/features/0015.npy
#   inflating: /content/data/train/features/0016.npy
#   inflating: /content/data/train/features/0017.npy
#   inflating: /content/data/train/features/0018.npy
#   inflating: /content/data/train/features/0019.npy
#   inflating: /content/data/train/features/0020.npy
#   inflating: /content/data/train/features/0021.npy
#   inflating: /content/data/train/features/0022.npy
#   inflating: /content/data/train/features/0023.npy
#   inflating: /content/data/train/features/0024.npy
#   inflating: /content/data/train/features/0025.npy
#   inflating: /content/data/train/features/0026.npy
#   inflating: /content/data/train/features/0027.npy
#   inflating: /content/data/train/features/0028.npy
#   inflating: /content/data/train/features/0029.npy
#   inflating: /content/data/train/features/0030.npy
#   inflating: /content/data/train/features/0031.npy
#   inflating: /content/data/train/features/0032.npy
#   inflating: /content/data/train/features/0033.npy
#   inflating: /content/data/train/features/0034.npy
#   inflating: /content/data/train/features/0035.npy
#   inflating: /content/data/train/features/0036.npy
#   inflating: /content/data/train/features/0037.npy
#   inflating: /content/data/train/features/0038.npy
#   inflating: /content/data/train/features/0039.npy
#   inflating: /content/data/train/features/0040.npy
#   inflating: /content/data/train/features/0041.npy
#   inflating: /content/data/train/features/0042.npy
#   inflating: /content/data/train/features/0043.npy
#   inflating: /content/data/train/features/0044.npy
#   inflating: /content/data/train/features/0045.npy
#   inflating: /content/data/train/features/0046.npy
#   inflating: /content/data/train/features/0047.npy
#   inflating: /content/data/train/features/0048.npy
#   inflating: /content/data/train/features/0049.npy
#   inflating: /content/data/train/features/0050.npy
#   inflating: /content/data/train/features/0051.npy
#   inflating: /content/data/train/features/0052.npy
#   inflating: /content/data/train/features/0053.npy
#   inflating: /content/data/train/features/0054.npy
#   inflating: /content/data/train/features/0055.npy
#   inflating: /content/data/train/features/0056.npy
#   inflating: /content/data/train/features/0057.npy
#   inflating: /content/data/train/features/0058.npy
#   inflating: /content/data/train/features/0059.npy
#   inflating: /content/data/train/features/0060.npy
#   inflating: /content/data/train/features/0061.npy
#   inflating: /content/data/train/features/0062.npy
#   inflating: /content/data/train/features/0063.npy
#   inflating: /content/data/train/features/0064.npy
#   inflating: /content/data/train/features/0065.npy
#   inflating: /content/data/train/features/0066.npy
#   inflating: /content/data/train/features/0067.npy
#   inflating: /content/data/train/features/0068.npy
#   inflating: /content/data/train/features/0069.npy
#   inflating: /content/data/train/features/0070.npy
#   inflating: /content/data/train/features/0071.npy
#   inflating: /content/data/train/features/0072.npy
#   inflating: /content/data/train/features/0073.npy
#   inflating: /content/data/train/features/0074.npy
#   inflating: /content/data/train/features/0075.npy
#   inflating: /content/data/train/features/0076.npy
#   inflating: /content/data/train/features/0077.npy
#   inflating: /content/data/train/features/0078.npy
#   inflating: /content/data/train/features/0079.npy
#   inflating: /content/data/train/features/0080.npy
#   inflating: /content/data/train/features/0081.npy
#   inflating: /content/data/train/features/0082.npy
#   inflating: /content/data/train/features/0083.npy
#   inflating: /content/data/train/features/0084.npy
#   inflating: /content/data/train/features/0085.npy
#   inflating: /content/data/train/features/0086.npy
#   inflating: /content/data/train/features/0087.npy
#   inflating: /content/data/train/features/0088.npy
#   inflating: /content/data/train/features/0089.npy
#   inflating: /content/data/train/features/0090.npy
#   inflating: /content/data/train/features/0091.npy
#   inflating: /content/data/train/features/0092.npy
#   inflating: /content/data/train/features/0093.npy
#   inflating: /content/data/train/features/0094.npy
#   inflating: /content/data/train/features/0095.npy
#   inflating: /content/data/train/features/0096.npy
#   inflating: /content/data/train/features/0097.npy
#   inflating: /content/data/train/features/0098.npy
#   inflating: /content/data/train/features/0099.npy
#   inflating: /content/data/train/features/0100.npy
#   inflating: /content/data/train/features/0101.npy
#   inflating: /content/data/train/features/0102.npy
#   inflating: /content/data/train/features/0103.npy
#   inflating: /content/data/train/features/0104.npy
#   inflating: /content/data/train/features/0105.npy
#   inflating: /content/data/train/features/0106.npy
#   inflating: /content/data/train/features/0107.npy
#   inflating: /content/data/train/features/0108.npy
#   inflating: /content/data/train/features/0109.npy
#   inflating: /content/data/train/features/0110.npy
#   inflating: /content/data/train/features/0111.npy
#   inflating: /content/data/train/features/0112.npy
#   inflating: /content/data/train/features/0113.npy
#   inflating: /content/data/train/features/0114.npy
#   inflating: /content/data/train/features/0115.npy
#   inflating: /content/data/train/features/0116.npy
#   inflating: /content/data/train/features/0117.npy
#   inflating: /content/data/train/features/0118.npy
#   inflating: /content/data/train/features/0119.npy
#   inflating: /content/data/train/features/0120.npy
#   inflating: /content/data/train/features/0121.npy
#   inflating: /content/data/train/features/0122.npy
#   inflating: /content/data/train/features/0123.npy
#   inflating: /content/data/train/features/0124.npy
#   inflating: /content/data/train/features/0125.npy
#   inflating: /content/data/train/features/0126.npy
#   inflating: /content/data/train/features/0127.npy
#   inflating: /content/data/train/features/0128.npy
#   inflating: /content/data/train/features/0129.npy
#   inflating: /content/data/train/features/0130.npy
#   inflating: /content/data/train/features/0131.npy
#   inflating: /content/data/train/features/0132.npy
#   inflating: /content/data/train/features/0133.npy
#   inflating: /content/data/train/features/0134.npy
#   inflating: /content/data/train/features/0135.npy
#   inflating: /content/data/train/features/0136.npy
#   inflating: /content/data/train/features/0137.npy
#   inflating: /content/data/train/features/0138.npy
#   inflating: /content/data/train/features/0139.npy
#   inflating: /content/data/train/features/0140.npy
#   inflating: /content/data/train/features/0141.npy
#   inflating: /content/data/train/features/0142.npy
#   inflating: /content/data/train/features/0143.npy
#   inflating: /content/data/train/features/0144.npy
#   inflating: /content/data/train/features/0145.npy
#   inflating: /content/data/train/features/0146.npy
#   inflating: /content/data/train/features/0147.npy
#   inflating: /content/data/train/features/0148.npy
#   inflating: /content/data/train/features/0149.npy
#   inflating: /content/data/train/features/0150.npy
#   inflating: /content/data/train/features/0151.npy
#   inflating: /content/data/train/features/0152.npy
#   inflating: /content/data/train/features/0153.npy
#   inflating: /content/data/train/features/0154.npy
#   inflating: /content/data/train/features/0155.npy
#   inflating: /content/data/train/features/0156.npy
#   inflating: /content/data/train/features/0157.npy
#   inflating: /content/data/train/features/0158.npy
#   inflating: /content/data/train/features/0159.npy
#   inflating: /content/data/train/features/0160.npy
#   inflating: /content/data/train/features/0161.npy
#   inflating: /content/data/train/features/0162.npy
#   inflating: /content/data/train/features/0163.npy
#   inflating: /content/data/train/features/0164.npy
#   inflating: /content/data/train/features/0165.npy
#   inflating: /content/data/train/features/0166.npy
#   inflating: /content/data/train/features/0167.npy
#   inflating: /content/data/train/features/0168.npy
#   inflating: /content/data/train/features/0169.npy
#   inflating: /content/data/train/features/0170.npy
#   inflating: /content/data/train/features/0171.npy
#   inflating: /content/data/train/features/0172.npy
#   inflating: /content/data/train/features/0173.npy
#   inflating: /content/data/train/features/0174.npy
#   inflating: /content/data/train/features/0175.npy
#   inflating: /content/data/train/features/0176.npy
#   inflating: /content/data/train/features/0177.npy
#   inflating: /content/data/train/features/0178.npy
#   inflating: /content/data/train/features/0179.npy
#   inflating: /content/data/train/features/0180.npy
#   inflating: /content/data/train/features/0181.npy
#   inflating: /content/data/train/features/0182.npy
#   inflating: /content/data/train/features/0183.npy
#   inflating: /content/data/train/features/0184.npy
#   inflating: /content/data/train/features/0185.npy
#   inflating: /content/data/train/features/0186.npy
#   inflating: /content/data/train/features/0187.npy
#   inflating: /content/data/train/features/0188.npy
#   inflating: /content/data/train/features/0189.npy
#   inflating: /content/data/train/features/0190.npy
#   inflating: /content/data/train/features/0191.npy
#   inflating: /content/data/train/features/0192.npy
#   inflating: /content/data/train/features/0193.npy
#   inflating: /content/data/train/features/0194.npy
#   inflating: /content/data/train/features/0195.npy
#   inflating: /content/data/train/features/0196.npy
#   inflating: /content/data/train/features/0197.npy
#   inflating: /content/data/train/features/0198.npy
#   inflating: /content/data/train/features/0199.npy
#   inflating: /content/data/train/features/0200.npy
#   inflating: /content/data/train/features/0201.npy
#   inflating: /content/data/train/features/0202.npy
#   inflating: /content/data/train/features/0203.npy
#   inflating: /content/data/train/features/0204.npy
#   inflating: /content/data/train/features/0205.npy
#   inflating: /content/data/train/features/0206.npy
#   inflating: /content/data/train/features/0207.npy
#   inflating: /content/data/train/features/0208.npy
#   inflating: /content/data/train/features/0209.npy
#   inflating: /content/data/train/features/0210.npy
#   inflating: /content/data/train/features/0211.npy
#   inflating: /content/data/train/features/0212.npy
#   inflating: /content/data/train/features/0213.npy
#   inflating: /content/data/train/features/0214.npy
#   inflating: /content/data/train/features/0215.npy
#   inflating: /content/data/train/features/0216.npy
#   inflating: /content/data/train/features/0217.npy
#   inflating: /content/data/train/features/0218.npy
#   inflating: /content/data/train/features/0219.npy
#   inflating: /content/data/train/features/0220.npy
#   inflating: /content/data/train/features/0221.npy
#   inflating: /content/data/train/features/0222.npy
#   inflating: /content/data/train/features/0223.npy
#   inflating: /content/data/train/features/0224.npy
#   inflating: /content/data/train/features/0225.npy
#   inflating: /content/data/train/features/0226.npy
#   inflating: /content/data/train/features/0227.npy
#   inflating: /content/data/train/features/0228.npy
#   inflating: /content/data/train/features/0229.npy
#   inflating: /content/data/train/features/0230.npy
#   inflating: /content/data/train/features/0231.npy
#   inflating: /content/data/train/features/0232.npy
#   inflating: /content/data/train/features/0233.npy
#   inflating: /content/data/train/features/0234.npy
#   inflating: /content/data/train/features/0235.npy
#   inflating: /content/data/train/features/0236.npy
#   inflating: /content/data/train/features/0237.npy
#   inflating: /content/data/train/features/0238.npy
#   inflating: /content/data/train/features/0239.npy
#   inflating: /content/data/train/features/0240.npy
#   inflating: /content/data/train/features/0241.npy
#   inflating: /content/data/train/features/0242.npy
#   inflating: /content/data/train/features/0243.npy
#   inflating: /content/data/train/features/0244.npy
#   inflating: /content/data/train/features/0245.npy
#   inflating: /content/data/train/features/0246.npy
#   inflating: /content/data/train/features/0247.npy
#   inflating: /content/data/train/features/0248.npy
#   inflating: /content/data/train/features/0249.npy
#   inflating: /content/data/train/features/0250.npy
#   inflating: /content/data/train/features/0251.npy
#   inflating: /content/data/train/features/0252.npy
#   inflating: /content/data/train/features/0253.npy
#   inflating: /content/data/train/features/0254.npy
#   inflating: /content/data/train/features/0255.npy
#   inflating: /content/data/train/features/0256.npy
#   inflating: /content/data/train/features/0257.npy
#   inflating: /content/data/train/features/0258.npy
#   inflating: /content/data/train/features/0259.npy
#   inflating: /content/data/train/features/0260.npy
#   inflating: /content/data/train/features/0261.npy
#   inflating: /content/data/train/features/0262.npy
#   inflating: /content/data/train/features/0263.npy
#   inflating: /content/data/train/features/0264.npy
#   inflating: /content/data/train/features/0265.npy
#   inflating: /content/data/train/features/0266.npy
#   inflating: /content/data/train/features/0267.npy
#   inflating: /content/data/train/features/0268.npy
#   inflating: /content/data/train/features/0269.npy
#   inflating: /content/data/train/features/0270.npy
#   inflating: /content/data/train/features/0271.npy
#   inflating: /content/data/train/features/0272.npy
#   inflating: /content/data/train/features/0273.npy
#   inflating: /content/data/train/features/0274.npy
#   inflating: /content/data/train/features/0275.npy
#   inflating: /content/data/train/features/0276.npy
#   inflating: /content/data/train/features/0277.npy
#   inflating: /content/data/train/features/0278.npy
#   inflating: /content/data/train/features/0279.npy
#   inflating: /content/data/train/features/0280.npy
#   inflating: /content/data/train/features/0281.npy
#   inflating: /content/data/train/features/0282.npy
#   inflating: /content/data/train/features/0283.npy
#   inflating: /content/data/train/features/0284.npy
#   inflating: /content/data/train/features/0285.npy
#   inflating: /content/data/train/features/0286.npy
#   inflating: /content/data/train/features/0287.npy
#   inflating: /content/data/train/features/0288.npy
#   inflating: /content/data/train/features/0289.npy
#   inflating: /content/data/train/features/0290.npy
#   inflating: /content/data/train/features/0291.npy
#   inflating: /content/data/train/features/0292.npy
#   inflating: /content/data/train/features/0293.npy
#   inflating: /content/data/train/features/0294.npy
#   inflating: /content/data/train/features/0295.npy
#   inflating: /content/data/train/features/0296.npy
#   inflating: /content/data/train/features/0297.npy
#   inflating: /content/data/train/features/0298.npy
#   inflating: /content/data/train/features/0299.npy
#   inflating: /content/data/train/features/0300.npy
#   inflating: /content/data/train/features/0301.npy
#   inflating: /content/data/train/features/0302.npy
#   inflating: /content/data/train/features/0303.npy
#   inflating: /content/data/train/features/0304.npy
#   inflating: /content/data/train/features/0305.npy
#   inflating: /content/data/train/features/0306.npy
#   inflating: /content/data/train/features/0307.npy
#   inflating: /content/data/train/features/0308.npy
#   inflating: /content/data/train/features/0309.npy
#   inflating: /content/data/train/features/0310.npy
#   inflating: /content/data/train/features/0311.npy
#   inflating: /content/data/train/features/0312.npy
#   inflating: /content/data/train/features/0313.npy
#   inflating: /content/data/train/features/0314.npy
#   inflating: /content/data/train/features/0315.npy
#   inflating: /content/data/train/features/0316.npy
#   inflating: /content/data/train/features/0317.npy
#   inflating: /content/data/train/features/0318.npy
#   inflating: /content/data/train/features/0319.npy
#   inflating: /content/data/train/features/0320.npy
#   inflating: /content/data/train/features/0321.npy
#   inflating: /content/data/train/features/0322.npy
#   inflating: /content/data/train/features/0323.npy
#   inflating: /content/data/train/features/0324.npy
#   inflating: /content/data/train/features/0325.npy
#   inflating: /content/data/train/features/0326.npy
#   inflating: /content/data/train/features/0327.npy
#   inflating: /content/data/train/features/0328.npy
#   inflating: /content/data/train/features/0329.npy
#   inflating: /content/data/train/features/0330.npy
#   inflating: /content/data/train/features/0331.npy
#   inflating: /content/data/train/features/0332.npy
#   inflating: /content/data/train/features/0333.npy
#   inflating: /content/data/train/features/0334.npy
#   inflating: /content/data/train/features/0335.npy
#   inflating: /content/data/train/features/0336.npy
#   inflating: /content/data/train/features/0337.npy
#   inflating: /content/data/train/features/0338.npy
#   inflating: /content/data/train/features/0339.npy
#   inflating: /content/data/train/features/0340.npy
#   inflating: /content/data/train/features/0341.npy
#   inflating: /content/data/train/features/0342.npy
#   inflating: /content/data/train/features/0343.npy
#   inflating: /content/data/train/features/0344.npy
#   inflating: /content/data/train/features/0345.npy
#   inflating: /content/data/train/features/0346.npy
#   inflating: /content/data/train/features/0347.npy
#   inflating: /content/data/train/features/0348.npy
#   inflating: /content/data/train/features/0349.npy
#   inflating: /content/data/train/features/0350.npy
#   inflating: /content/data/train/features/0351.npy
#   inflating: /content/data/train/features/0352.npy
#   inflating: /content/data/train/features/0353.npy
#   inflating: /content/data/train/features/0354.npy
#   inflating: /content/data/train/features/0355.npy
#   inflating: /content/data/train/features/0356.npy
#   inflating: /content/data/train/features/0357.npy
#   inflating: /content/data/train/features/0358.npy
#   inflating: /content/data/train/features/0359.npy
#   inflating: /content/data/train/features/0360.npy
#   inflating: /content/data/train/features/0361.npy
#   inflating: /content/data/train/features/0362.npy
#   inflating: /content/data/train/features/0363.npy
#   inflating: /content/data/train/features/0364.npy
#   inflating: /content/data/train/features/0365.npy
#   inflating: /content/data/train/features/0366.npy
#   inflating: /content/data/train/features/0367.npy
#   inflating: /content/data/train/features/0368.npy
#   inflating: /content/data/train/features/0369.npy
#   inflating: /content/data/train/features/0370.npy
#   inflating: /content/data/train/features/0371.npy
#   inflating: /content/data/train/features/0372.npy
#   inflating: /content/data/train/features/0373.npy
#   inflating: /content/data/train/features/0374.npy
#   inflating: /content/data/train/features/0375.npy
#   inflating: /content/data/train/features/0376.npy
#   inflating: /content/data/train/features/0377.npy
#   inflating: /content/data/train/features/0378.npy
#   inflating: /content/data/train/features/0379.npy
#   inflating: /content/data/train/features/0380.npy
#   inflating: /content/data/train/features/0381.npy
#   inflating: /content/data/train/features/0382.npy
#   inflating: /content/data/train/features/0383.npy
#   inflating: /content/data/train/features/0384.npy
#   inflating: /content/data/train/features/0385.npy
#   inflating: /content/data/train/features/0386.npy
#   inflating: /content/data/train/features/0387.npy
#   inflating: /content/data/train/features/0388.npy
#   inflating: /content/data/train/features/0389.npy
#   inflating: /content/data/train/features/0390.npy
#   inflating: /content/data/train/features/0391.npy
#   inflating: /content/data/train/features/0392.npy
#   inflating: /content/data/train/features/0393.npy
#   inflating: /content/data/train/features/0394.npy
#   inflating: /content/data/train/features/0395.npy
#   inflating: /content/data/train/features/0396.npy
#   inflating: /content/data/train/features/0397.npy
#   inflating: /content/data/train/features/0398.npy
#   inflating: /content/data/train/features/0399.npy
#   inflating: /content/data/train/features/0400.npy
#   inflating: /content/data/train/features/0401.npy
#   inflating: /content/data/train/features/0402.npy
#   inflating: /content/data/train/features/0403.npy
#   inflating: /content/data/train/features/0404.npy
#   inflating: /content/data/train/features/0405.npy
#   inflating: /content/data/train/features/0406.npy
#   inflating: /content/data/train/features/0407.npy
#   inflating: /content/data/train/features/0408.npy
#   inflating: /content/data/train/features/0409.npy
#   inflating: /content/data/train/features/0410.npy
#   inflating: /content/data/train/features/0411.npy
#   inflating: /content/data/train/features/0412.npy
#   inflating: /content/data/train/features/0413.npy
#   inflating: /content/data/train/features/0414.npy
#   inflating: /content/data/train/features/0415.npy
#   inflating: /content/data/train/features/0416.npy
#   inflating: /content/data/train/features/0417.npy
#   inflating: /content/data/train/features/0418.npy
#   inflating: /content/data/train/features/0419.npy
#   inflating: /content/data/train/features/0420.npy
#   inflating: /content/data/train/features/0421.npy
#   inflating: /content/data/train/features/0422.npy
#   inflating: /content/data/train/features/0423.npy
#   inflating: /content/data/train/features/0424.npy
#   inflating: /content/data/train/features/0425.npy
#   inflating: /content/data/train/features/0426.npy
#   inflating: /content/data/train/features/0427.npy
#   inflating: /content/data/train/features/0428.npy
#   inflating: /content/data/train/features/0429.npy
#   inflating: /content/data/train/features/0430.npy
#   inflating: /content/data/train/features/0431.npy
#   inflating: /content/data/train/features/0432.npy
#   inflating: /content/data/train/features/0433.npy
#   inflating: /content/data/train/features/0434.npy
#   inflating: /content/data/train/features/0435.npy
#   inflating: /content/data/train/features/0436.npy
#   inflating: /content/data/train/features/0437.npy
#   inflating: /content/data/train/features/0438.npy
#   inflating: /content/data/train/features/0439.npy
#   inflating: /content/data/train/features/0440.npy
#   inflating: /content/data/train/features/0441.npy
#   inflating: /content/data/train/features/0442.npy
#   inflating: /content/data/train/features/0443.npy
#   inflating: /content/data/train/features/0444.npy
#   inflating: /content/data/train/features/0445.npy
#   inflating: /content/data/train/features/0446.npy
#   inflating: /content/data/train/features/0447.npy
#   inflating: /content/data/train/features/0448.npy
#   inflating: /content/data/train/features/0449.npy
#   inflating: /content/data/train/features/0450.npy
#   inflating: /content/data/train/features/0451.npy
#   inflating: /content/data/train/features/0452.npy
#   inflating: /content/data/train/features/0453.npy
#   inflating: /content/data/train/features/0454.npy
#   inflating: /content/data/train/features/0455.npy
#   inflating: /content/data/train/features/0456.npy
#   inflating: /content/data/train/features/0457.npy
#   inflating: /content/data/train/features/0458.npy
#   inflating: /content/data/train/features/0459.npy
#   inflating: /content/data/train/features/0460.npy
#   inflating: /content/data/train/features/0461.npy
#   inflating: /content/data/train/features/0462.npy
#   inflating: /content/data/train/features/0463.npy
#   inflating: /content/data/train/features/0464.npy
#   inflating: /content/data/train/features/0465.npy
#   inflating: /content/data/train/features/0466.npy
#   inflating: /content/data/train/features/0467.npy
#   inflating: /content/data/train/features/0468.npy
#   inflating: /content/data/train/features/0469.npy
#   inflating: /content/data/train/features/0470.npy
#   inflating: /content/data/train/features/0471.npy
#   inflating: /content/data/train/features/0472.npy
#   inflating: /content/data/train/features/0473.npy
#   inflating: /content/data/train/features/0474.npy
#   inflating: /content/data/train/features/0475.npy
#   inflating: /content/data/train/features/0476.npy
#   inflating: /content/data/train/features/0477.npy
#   inflating: /content/data/train/features/0478.npy
#   inflating: /content/data/train/features/0479.npy
#   inflating: /content/data/train/features/0480.npy
#   inflating: /content/data/train/features/0481.npy
#   inflating: /content/data/train/features/0482.npy
#   inflating: /content/data/train/features/0483.npy
#   inflating: /content/data/train/features/0484.npy
#   inflating: /content/data/train/features/0485.npy
#   inflating: /content/data/train/features/0486.npy
#   inflating: /content/data/train/features/0487.npy
#   inflating: /content/data/train/features/0488.npy
#   inflating: /content/data/train/features/0489.npy
#   inflating: /content/data/train/features/0490.npy
#   inflating: /content/data/train/features/0491.npy
#   inflating: /content/data/train/features/0492.npy
#   inflating: /content/data/train/features/0493.npy
#   inflating: /content/data/train/features/0494.npy
#   inflating: /content/data/train/features/0495.npy
#   inflating: /content/data/train/features/0496.npy
#   inflating: /content/data/train/features/0497.npy
#   inflating: /content/data/train/features/0498.npy
#   inflating: /content/data/train/features/0499.npy
#   inflating: /content/data/train/features/0500.npy
#   inflating: /content/data/train/features/0501.npy
#   inflating: /content/data/train/features/0502.npy
#   inflating: /content/data/train/features/0503.npy
#   inflating: /content/data/train/features/0504.npy
#   inflating: /content/data/train/features/0505.npy
#   inflating: /content/data/train/features/0506.npy
#   inflating: /content/data/train/features/0507.npy
#   inflating: /content/data/train/features/0508.npy
#   inflating: /content/data/train/features/0509.npy
#   inflating: /content/data/train/features/0510.npy
#   inflating: /content/data/train/features/0511.npy
#   inflating: /content/data/train/features/0512.npy
#   inflating: /content/data/train/features/0513.npy
#   inflating: /content/data/train/features/0514.npy
#   inflating: /content/data/train/features/0515.npy
#   inflating: /content/data/train/features/0516.npy
#   inflating: /content/data/train/features/0517.npy
#   inflating: /content/data/train/features/0518.npy
#   inflating: /content/data/train/features/0519.npy
#   inflating: /content/data/train/features/0520.npy
#   inflating: /content/data/train/features/0521.npy
#   inflating: /content/data/train/features/0522.npy
#   inflating: /content/data/train/features/0523.npy
#   inflating: /content/data/train/features/0524.npy
#   inflating: /content/data/train/features/0525.npy
#   inflating: /content/data/train/features/0526.npy
#   inflating: /content/data/train/features/0527.npy
#   inflating: /content/data/train/features/0528.npy
#   inflating: /content/data/train/features/0529.npy
#   inflating: /content/data/train/features/0530.npy
#   inflating: /content/data/train/features/0531.npy
#   inflating: /content/data/train/features/0532.npy
#   inflating: /content/data/train/features/0533.npy
#   inflating: /content/data/train/features/0534.npy
#   inflating: /content/data/train/features/0535.npy
#   inflating: /content/data/train/features/0536.npy
#   inflating: /content/data/train/features/0537.npy
#   inflating: /content/data/train/features/0538.npy
#   inflating: /content/data/train/features/0539.npy
#   inflating: /content/data/train/features/0540.npy
#   inflating: /content/data/train/features/0541.npy
#   inflating: /content/data/train/features/0542.npy
#   inflating: /content/data/train/features/0543.npy
#   inflating: /content/data/train/features/0544.npy
#   inflating: /content/data/train/features/0545.npy
#   inflating: /content/data/train/features/0546.npy
# ...
#   inflating: /content/data/val/features/0046.npy
#   inflating: /content/data/val/features/0047.npy
#   inflating: /content/data/val/features/0048.npy
#   inflating: /content/data/val/features/0049.npy
#   inflating: /content/data/val/features/0050.npy
#   inflating: /content/data/val/features/0051.npy
#   inflating: /content/data/val/features/0052.npy
#   inflating: /content/data/val/features/0053.npy
#   inflating: /content/data/val/features/0054.npy
#   inflating: /content/data/val/features/0055.npy
#   inflating: /content/data/val/features/0056.npy
#   inflating: /content/data/val/features/0057.npy
#   inflating: /content/data/val/features/0058.npy
#   inflating: /content/data/val/features/0059.npy
#   inflating: /content/data/val/features/0060.npy
#   inflating: /content/data/val/features/0061.npy
#   inflating: /content/data/val/features/0062.npy
#   inflating: /content/data/val/features/0063.npy
#   inflating: /content/data/val/features/0064.npy
#   inflating: /content/data/val/features/0065.npy
#   inflating: /content/data/val/features/0066.npy
#   inflating: /content/data/val/features/0067.npy
#   inflating: /content/data/val/features/0068.npy
#   inflating: /content/data/val/features/0069.npy
#   inflating: /content/data/val/features/0070.npy
#   inflating: /content/data/val/features/0071.npy
#   inflating: /content/data/val/features/0072.npy
#   inflating: /content/data/val/features/0073.npy
#   inflating: /content/data/val/features/0074.npy
#   inflating: /content/data/val/features/0075.npy
#   inflating: /content/data/val/features/0076.npy
#   inflating: /content/data/val/features/0077.npy
#   inflating: /content/data/val/features/0078.npy
#   inflating: /content/data/val/features/0079.npy
#   inflating: /content/data/val/features/0080.npy
#   inflating: /content/data/val/features/0081.npy
#   inflating: /content/data/val/features/0082.npy
#   inflating: /content/data/val/features/0083.npy
#   inflating: /content/data/val/features/0084.npy
#   inflating: /content/data/val/features/0085.npy
#   inflating: /content/data/val/features/0086.npy
#   inflating: /content/data/val/features/0087.npy
#   inflating: /content/data/val/features/0088.npy
#   inflating: /content/data/val/features/0089.npy
#   inflating: /content/data/val/features/0090.npy
#   inflating: /content/data/val/features/0091.npy
#   inflating: /content/data/val/features/0092.npy
#   inflating: /content/data/val/features/0093.npy
#   inflating: /content/data/val/features/0094.npy
#   inflating: /content/data/val/features/0095.npy
#   inflating: /content/data/val/features/0096.npy
#   inflating: /content/data/val/features/0097.npy
#   inflating: /content/data/val/features/0098.npy
#   inflating: /content/data/val/features/0099.npy
#   inflating: /content/data/val/features/0100.npy
#   inflating: /content/data/val/features/0101.npy
#   inflating: /content/data/val/features/0102.npy
#   inflating: /content/data/val/features/0103.npy
#   inflating: /content/data/val/features/0104.npy
#   inflating: /content/data/val/features/0105.npy
#   inflating: /content/data/val/features/0106.npy
#   inflating: /content/data/val/features/0107.npy
#   inflating: /content/data/val/features/0108.npy
#   inflating: /content/data/val/features/0109.npy
#   inflating: /content/data/val/features/0110.npy
#   inflating: /content/data/val/features/0111.npy
#   inflating: /content/data/val/features/0112.npy
#   inflating: /content/data/val/features/0113.npy
#   inflating: /content/data/val/features/0114.npy
#   inflating: /content/data/val/features/0115.npy
#   inflating: /content/data/val/features/0116.npy
#   inflating: /content/data/val/features/0117.npy
#   inflating: /content/data/val/features/0118.npy
#   inflating: /content/data/val/features/0119.npy
#   inflating: /content/data/val/features/0120.npy
#   inflating: /content/data/val/features/0121.npy
#   inflating: /content/data/val/features/0122.npy
#   inflating: /content/data/val/features/0123.npy
#   inflating: /content/data/val/features/0124.npy
#   inflating: /content/data/val/features/0125.npy
#   inflating: /content/data/val/features/0126.npy
#   inflating: /content/data/val/features/0127.npy
#   inflating: /content/data/val/features/0128.npy
#   inflating: /content/data/val/features/0129.npy
#   inflating: /content/data/val/features/0130.npy
#   inflating: /content/data/val/features/0131.npy
#   inflating: /content/data/val/features/0132.npy
#   inflating: /content/data/val/features/0133.npy
#   inflating: /content/data/val/features/0134.npy
#   inflating: /content/data/val/features/0135.npy
#   inflating: /content/data/val/features/0136.npy
#   inflating: /content/data/val/features/0137.npy
#   inflating: /content/data/val/features/0138.npy
#   inflating: /content/data/val/features/0139.npy
#   inflating: /content/data/val/features/0140.npy
#   inflating: /content/data/val/features/0141.npy
#   inflating: /content/data/val/features/0142.npy
#   inflating: /content/data/val/features/0143.npy
#   inflating: /content/data/val/features/0144.npy
#   inflating: /content/data/val/features/0145.npy
#   inflating: /content/data/val/features/0146.npy
#   inflating: /content/data/val/features/0147.npy
#   inflating: /content/data/val/features/0148.npy
#   inflating: /content/data/val/features/0149.npy
#   inflating: /content/data/val/features/0150.npy
#   inflating: /content/data/val/features/0151.npy
#   inflating: /content/data/val/features/0152.npy
#   inflating: /content/data/val/features/0153.npy
#   inflating: /content/data/val/features/0154.npy
#   inflating: /content/data/val/features/0155.npy
#   inflating: /content/data/val/features/0156.npy
#   inflating: /content/data/val/features/0157.npy
#   inflating: /content/data/val/features/0158.npy
#   inflating: /content/data/val/features/0159.npy
#   inflating: /content/data/val/features/0160.npy
#   inflating: /content/data/val/features/0161.npy
#   inflating: /content/data/val/features/0162.npy
#   inflating: /content/data/val/features/0163.npy
#   inflating: /content/data/val/features/0164.npy
#   inflating: /content/data/val/features/0165.npy
#   inflating: /content/data/val/features/0166.npy
#   inflating: /content/data/val/features/0167.npy
#   inflating: /content/data/val/features/0168.npy
#   inflating: /content/data/val/features/0169.npy
#   inflating: /content/data/val/features/0170.npy
#   inflating: /content/data/val/features/0171.npy
#   inflating: /content/data/val/features/0172.npy
#   inflating: /content/data/val/features/0173.npy
#   inflating: /content/data/val/features/0174.npy
#   inflating: /content/data/val/features/0175.npy
#   inflating: /content/data/val/features/0176.npy
#   inflating: /content/data/val/features/0177.npy
#   inflating: /content/data/val/features/0178.npy
#   inflating: /content/data/val/features/0179.npy
#   inflating: /content/data/val/features/0180.npy
#   inflating: /content/data/val/features/0181.npy
#    creating: /content/data/val/target/
#   inflating: /content/data/val/target/0000.npy
#   inflating: /content/data/val/target/0001.npy
#   inflating: /content/data/val/target/0002.npy
#   inflating: /content/data/val/target/0003.npy
#   inflating: /content/data/val/target/0004.npy
#   inflating: /content/data/val/target/0005.npy
#   inflating: /content/data/val/target/0006.npy
#   inflating: /content/data/val/target/0007.npy
#   inflating: /content/data/val/target/0008.npy
#   inflating: /content/data/val/target/0009.npy
#   inflating: /content/data/val/target/0010.npy
#   inflating: /content/data/val/target/0011.npy
#   inflating: /content/data/val/target/0012.npy
#   inflating: /content/data/val/target/0013.npy
#   inflating: /content/data/val/target/0014.npy
#   inflating: /content/data/val/target/0015.npy
#   inflating: /content/data/val/target/0016.npy
#   inflating: /content/data/val/target/0017.npy
#   inflating: /content/data/val/target/0018.npy
#   inflating: /content/data/val/target/0019.npy
#   inflating: /content/data/val/target/0020.npy
#   inflating: /content/data/val/target/0021.npy
#   inflating: /content/data/val/target/0022.npy
#   inflating: /content/data/val/target/0023.npy
#   inflating: /content/data/val/target/0024.npy
#   inflating: /content/data/val/target/0025.npy
#   inflating: /content/data/val/target/0026.npy
#   inflating: /content/data/val/target/0027.npy
#   inflating: /content/data/val/target/0028.npy
#   inflating: /content/data/val/target/0029.npy
#   inflating: /content/data/val/target/0030.npy
#   inflating: /content/data/val/target/0031.npy
#   inflating: /content/data/val/target/0032.npy
#   inflating: /content/data/val/target/0033.npy
#   inflating: /content/data/val/target/0034.npy
#   inflating: /content/data/val/target/0035.npy
#   inflating: /content/data/val/target/0036.npy
#   inflating: /content/data/val/target/0037.npy
#   inflating: /content/data/val/target/0038.npy
#   inflating: /content/data/val/target/0039.npy
#   inflating: /content/data/val/target/0040.npy
#   inflating: /content/data/val/target/0041.npy
#   inflating: /content/data/val/target/0042.npy
#   inflating: /content/data/val/target/0043.npy
#   inflating: /content/data/val/target/0044.npy
#   inflating: /content/data/val/target/0045.npy
#   inflating: /content/data/val/target/0046.npy
#   inflating: /content/data/val/target/0047.npy
#   inflating: /content/data/val/target/0048.npy
#   inflating: /content/data/val/target/0049.npy
#   inflating: /content/data/val/target/0050.npy
#   inflating: /content/data/val/target/0051.npy
#   inflating: /content/data/val/target/0052.npy
#   inflating: /content/data/val/target/0053.npy
#   inflating: /content/data/val/target/0054.npy
#   inflating: /content/data/val/target/0055.npy
#   inflating: /content/data/val/target/0056.npy
#   inflating: /content/data/val/target/0057.npy
#   inflating: /content/data/val/target/0058.npy
#   inflating: /content/data/val/target/0059.npy
#   inflating: /content/data/val/target/0060.npy
#   inflating: /content/data/val/target/0061.npy
#   inflating: /content/data/val/target/0062.npy
#   inflating: /content/data/val/target/0063.npy
#   inflating: /content/data/val/target/0064.npy
#   inflating: /content/data/val/target/0065.npy
#   inflating: /content/data/val/target/0066.npy
#   inflating: /content/data/val/target/0067.npy
#   inflating: /content/data/val/target/0068.npy
#   inflating: /content/data/val/target/0069.npy
#   inflating: /content/data/val/target/0070.npy
#   inflating: /content/data/val/target/0071.npy
#   inflating: /content/data/val/target/0072.npy
#   inflating: /content/data/val/target/0073.npy
#   inflating: /content/data/val/target/0074.npy
#   inflating: /content/data/val/target/0075.npy
#   inflating: /content/data/val/target/0076.npy
#   inflating: /content/data/val/target/0077.npy
#   inflating: /content/data/val/target/0078.npy
#   inflating: /content/data/val/target/0079.npy
#   inflating: /content/data/val/target/0080.npy
#   inflating: /content/data/val/target/0081.npy
#   inflating: /content/data/val/target/0082.npy
#   inflating: /content/data/val/target/0083.npy
#   inflating: /content/data/val/target/0084.npy
#   inflating: /content/data/val/target/0085.npy
#   inflating: /content/data/val/target/0086.npy
#   inflating: /content/data/val/target/0087.npy
#   inflating: /content/data/val/target/0088.npy
#   inflating: /content/data/val/target/0089.npy
#   inflating: /content/data/val/target/0090.npy
#   inflating: /content/data/val/target/0091.npy
#   inflating: /content/data/val/target/0092.npy
#   inflating: /content/data/val/target/0093.npy
#   inflating: /content/data/val/target/0094.npy
#   inflating: /content/data/val/target/0095.npy
#   inflating: /content/data/val/target/0096.npy
#   inflating: /content/data/val/target/0097.npy
#   inflating: /content/data/val/target/0098.npy
#   inflating: /content/data/val/target/0099.npy
#   inflating: /content/data/val/target/0100.npy
#   inflating: /content/data/val/target/0101.npy
#   inflating: /content/data/val/target/0102.npy
#   inflating: /content/data/val/target/0103.npy
#   inflating: /content/data/val/target/0104.npy
#   inflating: /content/data/val/target/0105.npy
#   inflating: /content/data/val/target/0106.npy
#   inflating: /content/data/val/target/0107.npy
#   inflating: /content/data/val/target/0108.npy
#   inflating: /content/data/val/target/0109.npy
#   inflating: /content/data/val/target/0110.npy
#   inflating: /content/data/val/target/0111.npy
#   inflating: /content/data/val/target/0112.npy
#   inflating: /content/data/val/target/0113.npy
#   inflating: /content/data/val/target/0114.npy
#   inflating: /content/data/val/target/0115.npy
#   inflating: /content/data/val/target/0116.npy
#   inflating: /content/data/val/target/0117.npy
#   inflating: /content/data/val/target/0118.npy
#   inflating: /content/data/val/target/0119.npy
#   inflating: /content/data/val/target/0120.npy
#   inflating: /content/data/val/target/0121.npy
#   inflating: /content/data/val/target/0122.npy
#   inflating: /content/data/val/target/0123.npy
#   inflating: /content/data/val/target/0124.npy
#   inflating: /content/data/val/target/0125.npy
#   inflating: /content/data/val/target/0126.npy
#   inflating: /content/data/val/target/0127.npy
#   inflating: /content/data/val/target/0128.npy
#   inflating: /content/data/val/target/0129.npy
#   inflating: /content/data/val/target/0130.npy
#   inflating: /content/data/val/target/0131.npy
#   inflating: /content/data/val/target/0132.npy
#   inflating: /content/data/val/target/0133.npy
#   inflating: /content/data/val/target/0134.npy
#   inflating: /content/data/val/target/0135.npy
#   inflating: /content/data/val/target/0136.npy
#   inflating: /content/data/val/target/0137.npy
#   inflating: /content/data/val/target/0138.npy
#   inflating: /content/data/val/target/0139.npy
#   inflating: /content/data/val/target/0140.npy
#   inflating: /content/data/val/target/0141.npy
#   inflating: /content/data/val/target/0142.npy
#   inflating: /content/data/val/target/0143.npy
#   inflating: /content/data/val/target/0144.npy
#   inflating: /content/data/val/target/0145.npy
#   inflating: /content/data/val/target/0146.npy
#   inflating: /content/data/val/target/0147.npy
#   inflating: /content/data/val/target/0148.npy
#   inflating: /content/data/val/target/0149.npy
#   inflating: /content/data/val/target/0150.npy
#   inflating: /content/data/val/target/0151.npy
#   inflating: /content/data/val/target/0152.npy
#   inflating: /content/data/val/target/0153.npy
#   inflating: /content/data/val/target/0154.npy
#   inflating: /content/data/val/target/0155.npy
#   inflating: /content/data/val/target/0156.npy
#   inflating: /content/data/val/target/0157.npy
#   inflating: /content/data/val/target/0158.npy
#   inflating: /content/data/val/target/0159.npy
#   inflating: /content/data/val/target/0160.npy
#   inflating: /content/data/val/target/0161.npy
#   inflating: /content/data/val/target/0162.npy
#   inflating: /content/data/val/target/0163.npy
#   inflating: /content/data/val/target/0164.npy
#   inflating: /content/data/val/target/0165.npy
#   inflating: /content/data/val/target/0166.npy
#   inflating: /content/data/val/target/0167.npy
#   inflating: /content/data/val/target/0168.npy
#   inflating: /content/data/val/target/0169.npy
#   inflating: /content/data/val/target/0170.npy
#   inflating: /content/data/val/target/0171.npy
#   inflating: /content/data/val/target/0172.npy
#   inflating: /content/data/val/target/0173.npy
#   inflating: /content/data/val/target/0174.npy
#   inflating: /content/data/val/target/0175.npy
#   inflating: /content/data/val/target/0176.npy
#   inflating: /content/data/val/target/0177.npy
#   inflating: /content/data/val/target/0178.npy
#   inflating: /content/data/val/target/0179.npy
#   inflating: /content/data/val/target/0180.npy
#   inflating: /content/data/val/target/0181.npy
#   inflating: /content/data/minmax_scaler_target.pkl
#   inflating: /content/data/robust_scaler_target.pkl

# %% [markdown]
# ## GRU

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# ------------------- Dataset -------------------
class FolderTimeSeriesDataset(Dataset):
    """
    PyTorch Dataset load từng file .npy từ folder:
    dataset_ts/train/val/test
        features/0000.npy
        target/0000.npy
    """
    def __init__(self, root_dir, time_in=30, time_out=1):
        self.feature_dir = os.path.join(root_dir, "features")
        self.target_dir  = self.feature_dir

        self.feature_files = sorted(os.listdir(self.feature_dir))
        self.target_files  = sorted(os.listdir(self.target_dir))
        assert len(self.feature_files) == len(self.target_files), "features != target"

        self.time_in = time_in
        self.time_out = time_out

        # Tạo danh sách index cho sliding window
        self.sample_indices = []
        total_timesteps = len(self.feature_files)
        for i in range(total_timesteps - time_in - time_out + 1):
            self.sample_indices.append(i)

    def __len__(self):
        return len(self.sample_indices)

    def __getitem__(self, idx):
        start_idx = self.sample_indices[idx]

        # Load input sequence
        X_list = []
        for i in range(start_idx, start_idx + self.time_in):
            feat = np.load(os.path.join(self.feature_dir, self.feature_files[i]))  # [H,W,C]
            feat = np.transpose(feat, (2,0,1))  # [C,H,W]
            X_list.append(feat)
        X = np.stack(X_list, axis=0)  # [time_in, C, H, W]

        # Load output sequence
        Y_list = []
        for i in range(start_idx + self.time_in, start_idx + self.time_in + self.time_out):
            targ = np.load(os.path.join(self.target_dir, self.target_files[i]))  # [H,W,C] (C=1)
            targ = np.transpose(targ, (2,0,1))  # [C,H,W]
            Y_list.append(targ)
        Y = np.stack(Y_list, axis=0)  # [time_out, C, H, W]

        return torch.FloatTensor(X), torch.FloatTensor(Y)

class ConvGRUCell(nn.Module):
    def __init__(self, input_dim, hidden_dim, kernel_size, bias=True):
        super().__init__()
        self.input_dim = input_dim
        self.hidden_dim = hidden_dim
        self.padding = kernel_size // 2
        self.bias = bias

        # Gộp x_t và h_{t-1} rồi conv ra 2 * hidden_dim (z, r)
        self.conv_gates = nn.Conv2d(
            in_channels=input_dim + hidden_dim,
            out_channels=2 * hidden_dim,
            kernel_size=kernel_size,
            padding=self.padding,
            bias=bias
        )

        # Conv cho candidate hidden state \tilde{h}_t
        self.conv_can = nn.Conv2d(
            in_channels=input_dim + hidden_dim,
            out_channels=hidden_dim,
            kernel_size=kernel_size,
            padding=self.padding,
            bias=bias
        )

    def forward(self, x, h_cur):
        """
        x: [B, C_in, H, W]
        h_cur: [B, hidden_dim, H, W]
        """
        # Tính z_t, r_t
        combined = torch.cat([x, h_cur], dim=1)  # [B, C_in + hidden_dim, H, W]
        gates = self.conv_gates(combined)        # [B, 2*hidden_dim, H, W]
        z_gate, r_gate = torch.split(gates, self.hidden_dim, dim=1)

        z = torch.sigmoid(z_gate)
        r = torch.sigmoid(r_gate)

        # Candidate hidden state
        combined_reset = torch.cat([x, r * h_cur], dim=1)
        h_tilde = torch.tanh(self.conv_can(combined_reset))

        # Cập nhật hidden
        h_next = (1 - z) * h_cur + z * h_tilde
        return h_next

    def init_hidden(self, batch_size, image_size, device):
        H, W = image_size
        return torch.zeros(batch_size, self.hidden_dim, H, W, device=device)

class ConvGRU(nn.Module):
    def __init__(self, input_dim, hidden_dim, kernel_size, num_layers,
                 batch_first=True, bias=True, return_all_layers=False):
        super().__init__()
        self.input_dim = input_dim
        self.hidden_dim = hidden_dim if isinstance(hidden_dim, list) else [hidden_dim] * num_layers
        self.num_layers = num_layers
        self.batch_first = batch_first
        self.return_all_layers = return_all_layers

        self.cell_list = nn.ModuleList()
        for i in range(num_layers):
            cur_in = input_dim if i == 0 else self.hidden_dim[i-1]
            self.cell_list.append(
                ConvGRUCell(cur_in, self.hidden_dim[i], kernel_size, bias=bias)
            )

    def forward(self, x, hidden_state=None):
        """
        x: [B, T, C, H, W] nếu batch_first=True
        hidden_state: list length = num_layers, mỗi phần tử là h_0 shape [B, hidden_dim, H, W]
        """
        if not self.batch_first:
            x = x.permute(1, 0, 2, 3, 4)  # [T,B,C,H,W] -> [B,T,C,H,W]

        B, T, C, H, W = x.size()
        device = x.device

        # Khởi tạo hidden nếu chưa có
        if hidden_state is None:
            hidden_state = [cell.init_hidden(B, (H, W), device) for cell in self.cell_list]

        layer_output_list = []
        last_state_list = []

        cur_input = x
        for layer_idx in range(self.num_layers):
            h = hidden_state[layer_idx]
            output_inner = []

            for t in range(T):
                h = self.cell_list[layer_idx](cur_input[:, t], h)  # [B, hidden_dim, H, W]
                output_inner.append(h)

            layer_out = torch.stack(output_inner, dim=1)  # [B, T, hidden_dim, H, W]
            cur_input = layer_out

            layer_output_list.append(layer_out)
            last_state_list.append(h)  # chỉ có h, không có c

        if not self.return_all_layers:
            layer_output_list = layer_output_list[-1:]   # list 1 phần tử
            last_state_list = last_state_list[-1:]       # list 1 phần tử

        return layer_output_list, last_state_list


class ConvGRUForecaster(nn.Module):
    def __init__(self, input_channels,
                 hidden_dims=[64, 32, 16],
                 kernel_size=3,
                 dropout_rate=0.2,
                 time_out=7):
        super().__init__()
        self.time_out = time_out

        # ENCODER: giống ConvGRU cũ
        self.encoder = ConvGRU(
            input_dim=input_channels,
            hidden_dim=hidden_dims,
            kernel_size=kernel_size,
            num_layers=len(hidden_dims),
            batch_first=True,
            return_all_layers=True
        )

        # DECODER: nhận hidden của encoder, sinh ra chuỗi future
        # input_dim = hidden_dim cuối
        self.decoder = ConvGRU(
            input_dim=hidden_dims[-1],
            hidden_dim=hidden_dims,
            kernel_size=kernel_size,
            num_layers=len(hidden_dims),
            batch_first=True,
            return_all_layers=True
        )

        # token khởi đầu cho decoder
        self.start_token = nn.Parameter(
            torch.zeros(1, hidden_dims[-1], 1, 1)
        )

        self.dropout = nn.Dropout2d(dropout_rate)
        self.output_conv = nn.Conv2d(
            in_channels=hidden_dims[-1],
            out_channels=input_channels,
            kernel_size=3,
            padding=1
        )

    def forward(self, x):
        """
        x: [B, T_in, C, H, W]
        return: [B, time_out, C, H, W]
        """
        B, T_in, C, H, W = x.size()
        device = x.device

        # -------- ENCODER --------
        encoder_outs, encoder_states = self.encoder(x)
        # encoder_states is a list, lấy layer cuối:
        h_enc = encoder_states[-1]        # [B, hidden_last, H, W]

        # -------- DECODER --------
        outputs = []

        # decoder input ban đầu: start_token (giống “<GO>” token)
        dec_in = self.start_token.expand(B, -1, H, W)  # [B, hidden_last, H, W]

        # h0 cho decoder = h_enc cho mọi layer
        # encoder_states: list các h của từng layer → dùng lại luôn
        dec_hidden = encoder_states

        for _ in range(self.time_out):
            # decoder nhận 1 bước thời gian (T_dec = 1)
            dec_in_step = dec_in.unsqueeze(1)          # [B,1,hidden_last,H,W]
            dec_outs, dec_hidden = self.decoder(dec_in_step, dec_hidden)
            # dec_outs: list 1 phần tử (layer cuối): [B,1,hidden_last,H,W]
            h_dec_last = dec_hidden[-1]                # [B,hidden_last,H,W]

            h_dec_last = self.dropout(h_dec_last)
            feat_t = self.output_conv(h_dec_last)      # [B,C,H,W]
            outputs.append(feat_t)

            # cập nhật input cho bước tiếp theo (nếu muốn không autoregressive thì có thể dùng lại start_token)
            dec_in = h_dec_last

        # [time_out, B, C, H, W] -> [B, time_out, C, H, W]
        outputs = torch.stack(outputs, dim=1)
        return outputs


# ------------------- Training -------------------
def train_model(model, train_loader, val_loader, epochs=20, lr=0.001,
                device='cuda', checkpoint_path='best_model.pth'):
    """
    Huấn luyện mô hình PyTorch với tqdm progress bars
    """
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='min', factor=0.5, patience=7, min_lr=1e-6
    )

    best_val_loss = float('inf')
    patience_counter = 0
    patience = 15

    history = {'train_loss': [], 'train_mae': [], 'val_loss': [], 'val_mae': []}

    print(f"\n{'='*60}")
    print(f"🚀 Training ConvLSTM Model on {device}")
    print(f"{'='*60}")
    print(f"Training batches: {len(train_loader)}")
    print(f"Validation batches: {len(val_loader)}")
    print(f"Max epochs: {epochs}")
    print(f"{'='*60}\n")

    for epoch in range(epochs):
        # Training
        model.train()
        train_loss = 0.0
        train_mae = 0.0

        # Progress bar cho training
        train_pbar = tqdm(train_loader, desc=f'Epoch {epoch+1}/{epochs} [Train]',
                         leave=False, ncols=100)

        for batch_idx, (inputs, targets) in enumerate(train_pbar):
            inputs, targets = inputs.to(device), targets.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)

            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            train_mae += torch.mean(torch.abs(outputs - targets)).item()

            # Update progress bar
            train_pbar.set_postfix({
                'loss': f'{loss.item():.6f}',
                'mae': f'{torch.mean(torch.abs(outputs - targets)).item():.6f}'
            })

        train_loss /= len(train_loader)
        train_mae /= len(train_loader)

        # Validation
        model.eval()
        val_loss = 0.0
        val_mae = 0.0

        # Progress bar cho validation
        val_pbar = tqdm(val_loader, desc=f'Epoch {epoch+1}/{epochs} [Val]',
                       leave=False, ncols=100)

        with torch.no_grad():
            for inputs, targets in val_pbar:
                inputs, targets = inputs.to(device), targets.to(device)
                outputs = model(inputs)

                batch_loss = criterion(outputs, targets).item()
                batch_mae = torch.mean(torch.abs(outputs - targets)).item()

                val_loss += batch_loss
                val_mae += batch_mae

                # Update progress bar
                val_pbar.set_postfix({
                    'loss': f'{batch_loss:.6f}',
                    'mae': f'{batch_mae:.6f}'
                })

        val_loss /= len(val_loader)
        val_mae /= len(val_loader)

        # Learning rate scheduling
        scheduler.step(val_loss)

        # Save history
        history['train_loss'].append(train_loss)
        history['train_mae'].append(train_mae)
        history['val_loss'].append(val_loss)
        history['val_mae'].append(val_mae)

        # Print epoch summary
        print(f"Epoch {epoch+1}/{epochs} - "
              f"Train Loss: {train_loss:.6f}, Train MAE: {train_mae:.6f}, "
              f"Val Loss: {val_loss:.6f}, Val MAE: {val_mae:.6f}")

        # Early stopping and checkpointing
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            patience_counter = 0
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'val_loss': val_loss,
            }, checkpoint_path)
            print(f"  ✓ Model saved (val_loss: {val_loss:.6f})")
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print(f"\n⏹ Early stopping triggered after {epoch+1} epochs")
                break

    print(f"\n{'='*60}")
    print(f"✅ Training completed!")
    print(f"Best validation loss: {best_val_loss:.6f}")
    print(f"{'='*60}\n")

    return history



def multi_step_forecast(model, initial_seq, device='cuda'):
    """
    initial_seq: [1, time_in, C, H, W]
    return: np.ndarray [time_out, C, H, W]
    """
    model.eval()
    with torch.no_grad():
        out = model(initial_seq.to(device))  # [1, time_out, C, H, W]
    return out.squeeze(0).cpu().numpy()      # [time_out, C, H, W]



# ------------------- Visualization -------------------
def visualize_training(history):
    plt.figure(figsize=(10,4))
    plt.plot(history['train_loss'], label='Train Loss')
    plt.plot(history['val_loss'], label='Val Loss')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

def visualize_results(history, true_data, predictions, feature_names=None, save_path=None):
    """
    Visualize training results và predictions
    true_data, predictions: (n_days, C, H, W) format
    """
    n_days, C, H, W = predictions.shape

    if feature_names is None:
        feature_names = [f'Feature_{i}' for i in range(C)]

    # 1. Training curves
    fig, axes = plt.subplots(1, 2, figsize=(14, 4))

    axes[0].plot(history['train_loss'], label='Train Loss', linewidth=2)
    axes[0].plot(history['val_loss'], label='Val Loss', linewidth=2)
    axes[0].set_xlabel('Epoch', fontsize=12)
    axes[0].set_ylabel('MSE Loss', fontsize=12)
    axes[0].set_title('Training & Validation Loss', fontsize=14, fontweight='bold')
    axes[0].legend()
    axes[0].grid(True, alpha=0.3)

    axes[1].plot(history['train_mae'], label='Train MAE', linewidth=2)
    axes[1].plot(history['val_mae'], label='Val MAE', linewidth=2)
    axes[1].set_xlabel('Epoch', fontsize=12)
    axes[1].set_ylabel('MAE', fontsize=12)
    axes[1].set_title('Training & Validation MAE', fontsize=14, fontweight='bold')
    axes[1].legend()
    axes[1].grid(True, alpha=0.3)

    plt.tight_layout()
    if save_path:
        plt.savefig(f'{save_path}_training.png', dpi=150, bbox_inches='tight')
    plt.show()

    # 2. Spatial predictions
    n_features_show = min(3, C)
    n_days_show = min(3, n_days)

    fig, axes = plt.subplots(n_days_show, n_features_show * 2,
                            figsize=(4*n_features_show*2, 4*n_days_show))

    if n_days_show == 1:
        axes = axes.reshape(1, -1)

    for day_idx in range(n_days_show):
        for feat_idx in range(n_features_show):
            # True
            ax_true = axes[day_idx, feat_idx*2]
            im1 = ax_true.imshow(true_data[day_idx, feat_idx, :, :],
                                cmap='viridis', vmin=0, vmax=1)
            ax_true.set_title(f'Day {day_idx+1} - {feature_names[feat_idx]} (True)',
                            fontweight='bold')
            ax_true.axis('off')
            plt.colorbar(im1, ax=ax_true, fraction=0.046)

            # Predicted
            ax_pred = axes[day_idx, feat_idx*2 + 1]
            im2 = ax_pred.imshow(predictions[day_idx, feat_idx, :, :],
                                cmap='viridis', vmin=0, vmax=1)
            ax_pred.set_title(f'Day {day_idx+1} - {feature_names[feat_idx]} (Pred)',
                            fontweight='bold')
            ax_pred.axis('off')
            plt.colorbar(im2, ax=ax_pred, fraction=0.046)

    plt.tight_layout()
    if save_path:
        plt.savefig(f'{save_path}_predictions.png', dpi=150, bbox_inches='tight')
    plt.show()

# %% [markdown]
# ## FPN

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from typing import Tuple, List, Optional
from tqdm import tqdm
import warnings
import torch.nn.functional as F
warnings.filterwarnings('ignore')


class TensorTimeSeriesDataset(Dataset):
    """
    Dataset PyTorch cho tensor 3D time-series lưu trên disk
    """
    def __init__(self, root_dir):
        """
        root_dir: đường dẫn tới folder 'train', 'val' hoặc 'test'
        """
        self.feature_dir = os.path.join(root_dir, "features")
        self.target_dir  = os.path.join(root_dir, "target")

        self.feature_files = sorted(os.listdir(self.feature_dir))
        self.target_files  = sorted(os.listdir(self.target_dir))

    def __len__(self):
        return len(self.feature_files)

    def __getitem__(self, idx):
        # Load feature và target
        feat_path = os.path.join(self.feature_dir, self.feature_files[idx])
        targ_path = os.path.join(self.target_dir, self.target_files[idx])

        feature = np.load(feat_path)  # [H, W, C]
        target  = np.load(targ_path)  # [H, W, 1]

        # Chuyển sang tensor và permute để Conv2D input: [C, H, W]
        feature = torch.from_numpy(feature).float().permute(2, 0, 1)  # [C,H,W]
        target  = torch.from_numpy(target).float().permute(2, 0, 1)   # [1,H,W]

        return feature, target


# ---------- Simple CNN backbone: trả ra 3 scale ----------
class SimpleBackbone(nn.Module):
    """
    Nhận 1 frame [B,C,H,W] -> trả [C2,C3,C4] với downsample 2,4,8 lần.
    """
    def __init__(self, in_channels=1, base_channels=32):
        super().__init__()
        # Stage 1: H,W
        self.conv1 = self._conv_block(in_channels, base_channels)
        # Stage 2: H/2,W/2
        self.conv2 = self._conv_block(base_channels, base_channels*2)
        # Stage 3: H/4,W/4
        self.conv3 = self._conv_block(base_channels*2, base_channels*4)

        self.pool = nn.MaxPool2d(2,2)

    def _conv_block(self, in_ch, out_ch):
        return nn.Sequential(
            nn.Conv2d(in_ch, out_ch, 3, padding=1),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_ch, out_ch, 3, padding=1),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
        )

    def forward(self, x):
        # x: [B,C,H,W]
        c1 = self.conv1(x)         # [B, F,   H,   W]
        p1 = self.pool(c1)         # [B, F,   H/2, W/2]
        c2 = self.conv2(p1)        # [B, 2F,  H/2, W/2]
        p2 = self.pool(c2)         # [B, 2F,  H/4, W/4]
        c3 = self.conv3(p2)        # [B, 4F,  H/4, W/4]
        return c1, c2, c3          # 3 scale

# ---------- FPN ----------
class FPN(nn.Module):
    """
    Nhận [C1 (H,W), C2 (H/2,W/2), C3 (H/4,W/4)]
    -> trả feature cuối ở full resolution H,W
    """
    def __init__(self, c1_channels, c2_channels, c3_channels, fpn_channels=64):
        super().__init__()
        # lateral convs
        self.lat_c1 = nn.Conv2d(c1_channels, fpn_channels, kernel_size=1)
        self.lat_c2 = nn.Conv2d(c2_channels, fpn_channels, kernel_size=1)
        self.lat_c3 = nn.Conv2d(c3_channels, fpn_channels, kernel_size=1)

        # smooth convs
        self.smooth1 = nn.Conv2d(fpn_channels, fpn_channels, kernel_size=3, padding=1)
        self.smooth2 = nn.Conv2d(fpn_channels, fpn_channels, kernel_size=3, padding=1)

    def forward(self, c1, c2, c3):
        # Top-down pathway
        p3 = self.lat_c3(c3)                     # [B,F,H/4,W/4]
        p2 = self._upsample_add(p3, self.lat_c2(c2))  # [B,F,H/2,W/2]
        p1 = self._upsample_add(p2, self.lat_c1(c1))  # [B,F,H,W]

        # Smooth
        p2 = self.smooth2(p2)
        p1 = self.smooth1(p1)

        return p1  # feature ở full resolution

    def _upsample_add(self, x, y):
        # upsample x lên size của y rồi cộng
        _, _, H, W = y.shape
        return F.interpolate(x, size=(H, W), mode="bilinear", align_corners=False) + y

class RainfallFPN(nn.Module):
    """
    Stage 2: dự đoán rainfall từ feature của 1 ngày (C,H,W)
    Input : [B,C,H,W]   (feature 1 ngày, đã scale)
    Output: [B,1,H,W]   (rainfall scaled)
    """
    def __init__(self, in_channels, base_channels=32, fpn_channels=64, dropout_rate=0.1):
        super().__init__()
        self.backbone = SimpleBackbone(in_channels=in_channels,
                                       base_channels=base_channels)

        self.fpn = FPN(
            c1_channels=base_channels,
            c2_channels=base_channels*2,
            c3_channels=base_channels*4,
            fpn_channels=fpn_channels
        )

        self.dropout = nn.Dropout2d(dropout_rate)
        self.head = nn.Conv2d(fpn_channels, 1, kernel_size=3, padding=1)

    def forward(self, x):
        """
        x: [B,C,H,W]  (1 ngày feature)
        """
        c1, c2, c3 = self.backbone(x)   # 3 scale
        fpn_feat = self.fpn(c1, c2, c3) # [B,fpn_channels,H,W]
        fpn_feat = self.dropout(fpn_feat)
        out = self.head(fpn_feat)       # [B,1,H,W] rainfall (scaled)
        return out



# ==================== TRAINING FUNCTION ====================
def train_model_unet(model, train_loader, val_loader, epochs, lr, device, checkpoint_path):
    """
    Huấn luyện mô hình U-Net với tqdm progress bars
    """
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='min', factor=0.5, patience=7, min_lr=1e-6
    )

    best_val_loss = float('inf')
    patience_counter = 0
    patience = 15

    history = {'train_loss': [], 'train_mae': [], 'val_loss': [], 'val_mae': []}

    print(f"\n{'='*60}")
    print(f"🚀 Training U-Net Model on {device}")
    print(f"{'='*60}")
    print(f"Training batches: {len(train_loader)}")
    print(f"Validation batches: {len(val_loader)}")
    print(f"Max epochs: {epochs}")
    print(f"{'='*60}\n")

    for epoch in range(epochs):
        # Training
        model.train()
        train_loss = 0.0
        train_mae = 0.0

        train_pbar = tqdm(train_loader, desc=f'Epoch {epoch+1}/{epochs} [Train]',
                         leave=False, ncols=100)

        for batch_idx, (inputs, targets) in enumerate(train_pbar):
            inputs, targets = inputs.to(device), targets.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)

            loss = criterion(outputs, targets)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            train_loss += loss.item()
            train_mae += torch.mean(torch.abs(outputs - targets)).item()

            train_pbar.set_postfix({
                'loss': f'{loss.item():.6f}',
                'mae': f'{torch.mean(torch.abs(outputs - targets)).item():.6f}'
            })

        train_loss /= len(train_loader)
        train_mae /= len(train_loader)

        # Validation
        model.eval()
        val_loss = 0.0
        val_mae = 0.0

        val_pbar = tqdm(val_loader, desc=f'Epoch {epoch+1}/{epochs} [Val]',
                       leave=False, ncols=100)

        with torch.no_grad():
            for inputs, targets in val_pbar:
                inputs, targets = inputs.to(device), targets.to(device)
                outputs = model(inputs)

                batch_loss = criterion(outputs, targets).item()
                batch_mae = torch.mean(torch.abs(outputs - targets)).item()

                val_loss += batch_loss
                val_mae += batch_mae

                val_pbar.set_postfix({
                    'loss': f'{batch_loss:.6f}',
                    'mae': f'{batch_mae:.6f}'
                })

        val_loss /= len(val_loader)
        val_mae /= len(val_loader)

        scheduler.step(val_loss)

        history['train_loss'].append(train_loss)
        history['train_mae'].append(train_mae)
        history['val_loss'].append(val_loss)
        history['val_mae'].append(val_mae)

        print(f"Epoch {epoch+1}/{epochs} - "
              f"Train Loss: {train_loss:.6f}, Train MAE: {train_mae:.6f}, "
              f"Val Loss: {val_loss:.6f}, Val MAE: {val_mae:.6f}, "
              f"LR: {optimizer.param_groups[0]['lr']:.2e}")

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            patience_counter = 0
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'val_loss': val_loss,
                'history': history
            }, checkpoint_path)
            print(f"  ✓ Model saved (val_loss: {val_loss:.6f})")
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print(f"\n⏹ Early stopping triggered after {epoch+1} epochs")
                break

    print(f"\n{'='*60}")
    print(f"✅ Training completed!")
    print(f"Best validation loss: {best_val_loss:.6f}")
    print(f"{'='*60}\n")

    return history



# ==================== VISUALIZATION ====================
def plot_training_history(history, save_path='training_history.png'):
    """
    Vẽ biểu đồ quá trình training
    """
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))

    # Loss plot
    axes[0].plot(history['train_loss'], label='Train Loss', linewidth=2)
    axes[0].plot(history['val_loss'], label='Val Loss', linewidth=2)
    axes[0].set_xlabel('Epoch', fontsize=12)
    axes[0].set_ylabel('MSE Loss', fontsize=12)
    axes[0].set_title('Training and Validation Loss', fontsize=14, fontweight='bold')
    axes[0].legend(fontsize=10)
    axes[0].grid(True, alpha=0.3)

    # MAE plot
    axes[1].plot(history['train_mae'], label='Train MAE', linewidth=2)
    axes[1].plot(history['val_mae'], label='Val MAE', linewidth=2)
    axes[1].set_xlabel('Epoch', fontsize=12)
    axes[1].set_ylabel('MAE', fontsize=12)
    axes[1].set_title('Training and Validation MAE', fontsize=14, fontweight='bold')
    axes[1].legend(fontsize=10)
    axes[1].grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    print(f"📈 Training history saved to {save_path}")
    plt.show()

def evaluate_model(model, test_loader, device, minmax=None, robust=None):
    """
    Đánh giá mô hình trên tập test.
    Nếu có scaler_target thì tự động inverse_transform để so sánh trên giá trị thật (mm/ngày).
    """
    model.eval()
    criterion = nn.MSELoss()

    total_loss = 0.0
    total_mae = 0.0
    all_predictions = []
    all_targets = []

    print("\n🔍 Evaluating model on test set...")

    with torch.no_grad():
        for inputs, targets in tqdm(test_loader, desc='Testing', ncols=100):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)

            loss = criterion(outputs, targets)
            mae = torch.mean(torch.abs(outputs - targets))

            total_loss += loss.item()
            total_mae += mae.item()

            all_predictions.append(outputs.cpu().numpy())
            all_targets.append(targets.cpu().numpy())

    avg_loss = total_loss / len(test_loader)
    avg_mae = total_mae / len(test_loader)

    preds = np.concatenate(all_predictions, axis=0)
    targets = np.concatenate(all_targets, axis=0)

    print(f"\n📊 Test Results (scaled):")
    print(f"  MSE Loss: {avg_loss:.6f}")
    print(f"  MAE: {avg_mae:.6f}")

    # ==============================
    # 🔁 Inverse transform (nếu có scaler)
    # ==============================
    if minmax is not None and robust is not None:
        # reshape về (N, H*W)
        N, C, H, W = preds.shape
        preds_2d = preds.reshape(-1, 1)
        targets_2d = targets.reshape(-1, 1)

        preds_inv = robust.inverse_transform(minmax.inverse_transform(preds_2d)).reshape(N, C, H, W)
        targets_inv = robust.inverse_transform(minmax.inverse_transform(targets_2d)).reshape(N, C, H, W)

        mse_real = np.mean((preds_inv - targets_inv) ** 2)
        mae_real = np.mean(np.abs(preds_inv - targets_inv))

        print(f"\n🌧️ Test Results (after inverse transform - mm/day):")
        print(f"  MSE: {mse_real:.6f}")
        print(f"  MAE: {mae_real:.6f}")

        return {
            'loss_scaled': avg_loss,
            'mae_scaled': avg_mae,
            'loss_real': mse_real,
            'mae_real': mae_real,
            'preds_scaled': preds,
            'targets_scaled': targets,
            'preds_real': preds_inv,
            'targets_real': targets_inv
        }

    return {
        'loss_scaled': avg_loss,
        'mae_scaled': avg_mae,
        'preds_scaled': preds,
        'targets_scaled': targets
    }

def visualize_predictions_last(predictions, targets, num_samples=3, channel=0, save_path='predictions.png'):
    """
    Hiển thị kết quả dự đoán
    """
    fig, axes = plt.subplots(num_samples, 3, figsize=(12, 4*num_samples))

    if num_samples == 1:
        axes = axes.reshape(1, -1)

    for i in range(num_samples):
        pred = predictions[i, channel]
        target = targets[i, channel]
        diff = np.abs(pred - target)

        # Target
        im1 = axes[i, 0].imshow(target, cmap='viridis')
        axes[i, 0].set_title(f'Sample {i+1}: Ground Truth', fontweight='bold')
        axes[i, 0].axis('off')
        plt.colorbar(im1, ax=axes[i, 0], fraction=0.046)

        # Prediction
        im2 = axes[i, 1].imshow(pred, cmap='viridis')
        axes[i, 1].set_title(f'Sample {i+1}: Prediction', fontweight='bold')
        axes[i, 1].axis('off')
        plt.colorbar(im2, ax=axes[i, 1], fraction=0.046)

        # Difference
        im3 = axes[i, 2].imshow(diff, cmap='Reds')
        axes[i, 2].set_title(f'Sample {i+1}: Absolute Error', fontweight='bold')
        axes[i, 2].axis('off')
        plt.colorbar(im3, ax=axes[i, 2], fraction=0.046)

    plt.tight_layout()
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    print(f"🖼️  Predictions saved to {save_path}")
    plt.show()

# %% [markdown]
# ## PREDICTION

# %%
# ================================================================
# 📦 Rainfall Prediction Pipeline (ConvGRU + FPN)
# Author: Thanh Huy
# ================================================================
from datetime import datetime
import numpy as np
import torch
import matplotlib.pyplot as plt
import geopandas as gpd
import joblib

time_in = 30   # số ngày input
time_out = 7   # số ngày output

train_dataset = FolderTimeSeriesDataset("data/train", time_in=time_in, time_out=time_out)
val_dataset   = FolderTimeSeriesDataset("data/val", time_in=time_in, time_out=time_out)
test_dataset  = FolderTimeSeriesDataset("data/test", time_in=time_in, time_out=time_out)

rain_train_dataset = TensorTimeSeriesDataset("data/train")
rain_val_dataset   = TensorTimeSeriesDataset("data/val")
rain_test_dataset  = TensorTimeSeriesDataset("data/test")

rain_train_loader = DataLoader(rain_train_dataset, batch_size=8, shuffle=True)
rain_val_loader   = DataLoader(rain_val_dataset,   batch_size=8, shuffle=False)
rain_test_loader  = DataLoader(rain_test_dataset,  batch_size=8, shuffle=False)

# ================================================================
# 🗺️ Visualization
# ================================================================
def plot_map(rain_map, title, vn_adm1, dbscl,
             min_lon=103.5, max_lon=107, min_lat=8, max_lat=11.5):
    """
    Hiển thị bản đồ dự đoán lượng mưa trên vùng ĐBSCL.
    rain_map: np.ndarray [H, W] – lượng mưa (mm/ngày)
    """
    extent = [min_lon, max_lon, min_lat, max_lat]
    fig, ax = plt.subplots(figsize=(10, 10))

    # Ranh giới hành chính
    vn_adm1.boundary.plot(ax=ax, color='lightgrey', linewidth=0.4)
    dbscl.boundary.plot(ax=ax, color='black', linewidth=1)

    # Overlay ma trận dự đoán
    im = ax.imshow(rain_map, extent=extent, origin='lower',
                   cmap='turbo', alpha=0.8)

    # Tùy chỉnh hiển thị
    plt.colorbar(im, ax=ax, label="Rainfall prediction (mm)")
    ax.set_title(title, fontsize=13)
    ax.set_xlabel("Kinh độ")
    ax.set_ylabel("Vĩ độ")
    ax.set_xlim(min_lon, max_lon)
    ax.set_ylim(min_lat, max_lat)
    plt.tight_layout()
    plt.show()





def inverse_scale_rainfall(pred_scaled, minmax, robust):
    """
    Inverse scaling cho rainfall từ không gian [0,1] (MinMax+Robust) về mm/ngày.

    Parameters
    ----------
    pred_scaled : np.ndarray hoặc torch.Tensor
        - shape [C, H, W] hoặc [H, W]
    minmax : sklearn MinMaxScaler
    robust : sklearn RobustScaler

    Returns
    -------
    np.ndarray
        Mảng [H, W] là rainfall (mm/ngày).
    """
    if isinstance(pred_scaled, torch.Tensor):
        pred_scaled = pred_scaled.detach().cpu().numpy()

    # Nếu còn channel dimension
    if pred_scaled.ndim == 3:  # [C, H, W]
        C, H, W = pred_scaled.shape
        flat = pred_scaled.reshape(-1, 1)
        inv = robust.inverse_transform(
            minmax.inverse_transform(flat)
        ).reshape(C, H, W)
        return inv[0]  # giả sử C=1 -> lấy channel 0
    elif pred_scaled.ndim == 2:  # [H, W]
        H, W = pred_scaled.shape
        flat = pred_scaled.reshape(-1, 1)
        inv = robust.inverse_transform(
            minmax.inverse_transform(flat)
        ).reshape(H, W)
        return inv
    else:
        raise ValueError(f"Unsupported pred_scaled shape: {pred_scaled.shape}")


# ================================================================
# 🚀 Main Pipeline (ConvGRU ➜ FPN)
# ================================================================
def main_predict(day, month, year):
    """
    Pipeline dự đoán lượng mưa cho một ngày cụ thể:
      1) Tính số ngày n_days từ 31/12/2024 đến (day,month,year)
      2) Dùng ConvGRUForecaster dự đoán chuỗi feature time_out ngày tới
      3) Lấy feature đúng ngày n_days (trong khoảng [1, time_out])
      4) Dùng RainfallFPN dự đoán rainfall từ feature của ngày đó
      5) Inverse scaling về mm/ngày
      6) Vẽ bản đồ ĐBSCL
    """
    # ----- Thông tin thời gian -----
    start_date = datetime(2024, 12, 31)
    end_date = datetime(year, month, day)
    n_days = (end_date - start_date).days
    print(f"⏳ Số ngày cần dự đoán từ 31/12/2024: {n_days} ngày")

    if n_days <= 0:
        raise ValueError("Ngày dự đoán phải sau 31/12/2024")

    device = 'cuda' if torch.cuda.is_available() else 'cpu'

    # ===== 1) Load ConvGRUForecaster (Stage 1) =====
    # train_dataset phải là FolderTimeSeriesDataset(...)
    X0, _ = train_dataset[0]          # X0: [time_in, C_in, H, W]
    input_channels = X0.shape[1]

    convgru_model = ConvGRUForecaster(
        input_channels=input_channels,
        hidden_dims=[64, 32, 16],
        kernel_size=3,
        dropout_rate=0.2,
        # 🔧 SỬA: phải truyền đúng time_out mà bạn đã train
        time_out=7
    ).to(device)

    ckpt_conv = torch.load('conv_gru_best.pth', map_location=device)
    convgru_model.load_state_dict(ckpt_conv['model_state_dict'])
    convgru_model.eval()

    # ===== 2) Load RainfallFPN (Stage 2) =====
    # rain_train_dataset phải là TensorTimeSeriesDataset(...)
    feat_sample, _ = rain_train_dataset[0]    # [C_feat, H, W]
    in_channels_fpn = feat_sample.shape[0]

    rain_model = RainfallFPN(
        in_channels=in_channels_fpn,
        base_channels=32,
        fpn_channels=64,
        dropout_rate=0.1
    ).to(device)

    ckpt_rain = torch.load('best_rainfall_fpn.pth', map_location=device)
    rain_model.load_state_dict(ckpt_rain['model_state_dict'])
    rain_model.eval()

    # (Optional) sanity check: số channel feature từ ConvGRU phải khớp FPN
    # ConvGRUForecaster output: C_feat = input_channels
    assert in_channels_fpn == input_channels, \
        f"Channel mismatch: ConvGRU out C={input_channels}, FPN in C={in_channels_fpn}"

    # ===== 3) Lấy chuỗi history cuối cùng (30 ngày feature) =====
    # test_dataset: FolderTimeSeriesDataset(...)
    pre_data, _ = test_dataset[-1]            # [time_in, C_in, H, W]
    pre_data = pre_data.unsqueeze(0).to(device)  # [1, time_in, C_in, H, W]

    # ===== 4) Dự đoán MULTI-STEP bằng ConvGRUForecaster =====
    # 🔧 SỬA: GỌI MỘT LẦN, KHÔNG AUTOREGRESSIVE NHIỀU LẦN NỮA
    with torch.no_grad():
        # features_future: [1, time_out, C_feat, H, W]
        features_future = convgru_model(pre_data)

    # Đảm bảo n_days nằm trong khoảng time_out
    time_out_model = features_future.shape[1]
    if n_days > time_out_model:
        raise ValueError(
            f"n_days = {n_days} > time_out của model = {time_out_model}. "
            f"Hãy train ConvGRU với time_out >= {n_days} hoặc dùng autoregressive."
        )

    # Lấy feature đúng ngày n_days (index n_days-1)
    # feat_last_scaled: [C_feat, H, W]
    feat_last_scaled = features_future[:, n_days - 1].squeeze(0).cpu().numpy()

    # ===== 5) Dự đoán rainfall từ feature ngày đó bằng FPN =====
    feat_last_tensor = torch.from_numpy(feat_last_scaled).unsqueeze(0).float().to(device)  # [1, C_feat, H, W]
    with torch.no_grad():
        rain_scaled = rain_model(feat_last_tensor)[0, 0].cpu().numpy()  # [H, W] (scaled)

    # ===== 6) Inverse scaling rainfall về mm/ngày =====
    minmax = joblib.load('/content/data/minmax_scaler_target.pkl')
    robust = joblib.load('/content/data/robust_scaler_target.pkl')

    pred_rain = inverse_scale_rainfall(rain_scaled, minmax, robust)  # [H, W] mm/ngày

    # ===== 7) Đọc shapefile & vẽ bản đồ =====
    vn_adm1 = gpd.read_file('/content/gadm41_VNM_1.json')
    mekong_provinces = [
        "LongAn", "TiềnGiang", "BếnTre", "TràVinh", "VĩnhLong",
        "ĐồngTháp", "AnGiang", "CầnThơ", "HậuGiang",
        "SócTrăng", "BạcLiêu", "CàMau", "KiênGiang"
    ]
    dbscl = vn_adm1[vn_adm1["NAME_1"].isin(mekong_provinces)]

    plot_map(
        pred_rain,
        title=f"Predicted Rainfall ({day}/{month}/{year})",
        vn_adm1=vn_adm1,
        dbscl=dbscl
    )


# ================================================================
# ▶️ Run Example
# ================================================================
if __name__ == "__main__":
    # Ví dụ: dự đoán lượng mưa ngày 05/01/2025
    for i in range(1, 8, 1):
      main_predict(day=i, month=1, year=2025)
# Out:
# ⏳ Số ngày cần dự đoán từ 31/12/2024: 1 ngày
# ⏳ Số ngày cần dự đoán từ 31/12/2024: 2 ngày
# ⏳ Số ngày cần dự đoán từ 31/12/2024: 3 ngày
# ⏳ Số ngày cần dự đoán từ 31/12/2024: 4 ngày
# ⏳ Số ngày cần dự đoán từ 31/12/2024: 5 ngày
# ⏳ Số ngày cần dự đoán từ 31/12/2024: 6 ngày
# ⏳ Số ngày cần dự đoán từ 31/12/2024: 7 ngày
